# %% [markdown]
# ### Задание:
# ###### - Скачать все вакансии СБЕРа с ХХ (у апи есть ограничение в 2000, а также captcha подумайте как их можно обойти)
# ###### - Извлеките все описания этих вакансий
# ###### - Создайте DataFrame добавьте поле skills
# ###### - Переведите даты публикаций в datetime
# ###### - Постройте график опубликованных вакансий по датам
# ###### - Переведите даты в дни недели, и определите день недели, в который больше всего публикуют вакансий
# ###### - Найдите те вакансии с использованием python, которые вам интересны
# ###### - Определите по полю skills какие навыки больше всего востребованы для этих вакансий
# ###### - Постройте график наиболее востребованных навыков для аналитика данных

# %%
import requests
from tqdm.auto import tqdm
import pandas as pd

# %%
sber = '3529'
page = 1
num_per_page = 100
moscow = 1
url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={page}&per_page={num_per_page}'

# %%
url = f'https://api.hh.ru/vacancies'
params = {
    'employer_id':sber,
    'page':page,
    'per_page':num_per_page,
}
res = requests.get(url, params=params)

# %% [markdown]
# ###### - Описание вакансий:

# %%
res.json()
# Out:
# {'items': [{'id': '68770674',
#    'premium': False,
#    'name': 'Старший менеджер по обслуживанию',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2076',
#     'name': 'Талдом',
#     'url': 'https://api.hh.ru/areas/2076'},
#    'salary': {'from': 68500, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Талдом',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 56.7308564,
#     'lng': 37.5276003,
#     'raw': 'Талдом',
#     'metro': None,
#     'metro_stations': [],
#     'id': '7647975'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-15T09:25:01+0300',
#    'created_at': '2022-08-15T09:25:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68770674',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68770674?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68770674/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68770674',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Владеешь программами Microsoft Office, Outlook. Готов к работе, предполагающей ежедневное проведение...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Осуществлять операции по обслуживанию клиентов. Проводить кассовые операции: прием, выдача, обмен денег. Предлагать продукты и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67740900',
#    'premium': False,
#    'name': 'Старший менеджер по обслуживанию',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2091',
#     'name': 'Красноармейск (Московская область)',
#     'url': 'https://api.hh.ru/areas/2091'},
#    'salary': {'from': 76000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Красноармейск',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 56.105426,
#     'lng': 38.140838,
#     'raw': 'Красноармейск',
#     'metro': None,
#     'metro_stations': [],
#     'id': '7648024'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-12T14:39:54+0300',
#    'created_at': '2022-08-12T14:39:54+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67740900',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67740900?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67740900/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67740900',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Владеешь программами Microsoft Office, Outlook. Готов к работе, предполагающей ежедневное проведение...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Осуществлять операции по обслуживанию клиентов. Проводить кассовые операции: прием, выдача, обмен денег. Предлагать продукты и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68838832',
#    'premium': False,
#    'name': 'Водитель-инкассатор',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 76500, 'to': 81500, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-16T13:29:57+0300',
#    'created_at': '2022-08-16T13:29:57+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68838832',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68838832?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68838832/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68838832',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Хорошую физическую подготовку. Подтвержденный стаж работы по найму водителем не менее года. Умение обращаться с оружием или готовность обучаться этому...',
#     'responsibility': 'Перевозка денежных средств, а также других ценностей. Загрузка/разгрузка банковских терминалов. Обеспечение сохранности перевозимых ценностей. Усиленные меры безопасности: современный бронированный...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68332722',
#    'premium': False,
#    'name': 'Водитель',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '49',
#     'name': 'Киров (Кировская область)',
#     'url': 'https://api.hh.ru/areas/49'},
#    'salary': {'from': 28700, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Киров',
#     'street': 'Дерендяева',
#     'building': '25',
#     'description': None,
#     'lat': 58.603942,
#     'lng': 49.661106,
#     'raw': 'Киров, Дерендяева, 25',
#     'metro': None,
#     'metro_stations': [],
#     'id': '11264065'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-01T11:15:31+0300',
#    'created_at': '2022-08-01T11:15:31+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68332722',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68332722?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68332722/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68332722',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Права категории В. Стаж вождения от 3 лет. Средне специальное образование. Дисциплинированность. Ответственность.',
#     'responsibility': 'Управление банковским спецавтомобилем. Соблюдение сроков объёма работ по техническому обслуживанию. Предупреждение поломки автомобиля, обслуживание. Обеспечение бесперебойной работы передвижного кассового пункта...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68850567',
#    'premium': False,
#    'name': 'Тестировщик (QA инженер)',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32к1',
#     'description': None,
#     'lat': 55.741338,
#     'lng': 37.531127,
#     'raw': 'Москва, Кутузовский проспект, 32к1',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'Филевская',
#      'station_id': '4.73',
#      'line_id': '4',
#      'lat': 55.740544,
#      'lng': 37.5341},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'Филевская',
#       'station_id': '4.73',
#       'line_id': '4',
#       'lat': 55.740544,
#       'lng': 37.5341},
#      {'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '731097'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-16T16:37:07+0300',
#    'created_at': '2022-08-16T16:37:07+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68850567',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68850567?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68850567/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68850567',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Понимание процесса разработки ПО. Опыт тестирования (включая REST API). Опыт работы с системами баг-трекинга. Опыт написания простых SQL-запросов. ',
#     'responsibility': 'Разработка функциональных тестов и развитие тестовой модели. Работа с системами баг-трекинга в части заведения и обработки дефектов. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68808474',
#    'premium': False,
#    'name': 'Менеджер по обслуживанию',
#    'department': {'id': '3529-3529-stat', 'name': 'Сбер. Начало карьеры'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2028',
#     'name': 'Истра',
#     'url': 'https://api.hh.ru/areas/2028'},
#    'salary': {'from': 67000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Истра',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 55.9061359,
#     'lng': 36.8600924,
#     'raw': 'Истра',
#     'metro': None,
#     'metro_stations': [],
#     'id': '11369282'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-15T21:09:32+0300',
#    'created_at': '2022-08-15T21:09:32+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68808474',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68808474?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68808474/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68808474',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Владеешь программами Microsoft Office, Outlook. Готов к работе, предполагающей ежедневное проведение...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Осуществлять операции по обслуживанию клиентов. Проводить кассовые операции: прием, выдача, обмен денег. Предлагать продукты и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68429605',
#    'premium': False,
#    'name': 'Лидер кластера',
#    'department': {'id': '3529-3529-lead',
#     'name': 'Сбер. Экспертам и руководителям'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-03T11:12:09+0300',
#    'created_at': '2022-08-03T11:12:09+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68429605',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68429605?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68429605/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68429605',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Успешный опыт управления проектами в B2B сегменте. Опыт работы с органами власти или с госструктурами, включая нормотворчество. ',
#     'responsibility': 'Развивать платежные сервисы и продукты в ПАО Сбербанк, создавать инновационные решения в рамках продукта. Формировать Roadmap развития продукта и реализовывать...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68064231',
#    'premium': False,
#    'name': 'Старший менеджер по обслуживанию',
#    'department': {'id': '3529-3529-clients',
#     'name': 'Сбер. Работа с клиентами'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '47',
#     'name': 'Кемерово',
#     'url': 'https://api.hh.ru/areas/47'},
#    'salary': {'from': 53500, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-22T12:59:56+0300',
#    'created_at': '2022-07-22T12:59:56+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68064231',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68064231?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68064231/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68064231',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Хочешь стать экспертом в банковской сфере. Доброжелателен и готов помогать клиентам. Специалист со средним профессиональным, неполным высшим или высшим образованием. ',
#     'responsibility': 'Осуществлять операции по обслуживанию клиентов. Проводить кассовые операции: прием, выдача, обмен денег. Предлагать продукты и сервисы Сбера. Консультировать клиентов по...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68326202',
#    'premium': False,
#    'name': 'Клиентский менеджер малого и микробизнеса',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '66',
#     'name': 'Нижний Новгород',
#     'url': 'https://api.hh.ru/areas/66'},
#    'salary': {'from': 52000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Нижний Новгород',
#     'street': 'проспект Ленина',
#     'building': '53',
#     'description': None,
#     'lat': 56.277823,
#     'lng': 43.921383,
#     'raw': 'Нижний Новгород, проспект Ленина, 53',
#     'metro': None,
#     'metro_stations': [],
#     'id': '11415410'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-01T09:56:27+0300',
#    'created_at': '2022-08-01T09:56:27+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68326202',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68326202?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68326202/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68326202',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'высшее образование (финансы/банки, экономика/бухгалтерия). - опыт в сфере продаж или обслуживания клиентов от 1 года. - грамотная и структурированная речь. - ',
#     'responsibility': 'консультировать корпоративных клиентов по продуктам банка и экосистемы. - обслуживать юридические лица при открытии расчётного счета. - формировать потребность клиента на комплексное...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68646330',
#    'premium': False,
#    'name': 'Трейдер',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-10T12:23:41+0300',
#    'created_at': '2022-08-10T12:23:41+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68646330',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68646330?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68646330/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68646330',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Математическое образование (ведущие ВУЗы). Опыт работы с опционами на любом типе активов от 1 года. Базовые знания моделей ценообразования валютных...',
#     'responsibility': 'Совместное управление портфелем валютных/процентных опционов. Привлечение потока клиентов. Управление собственными позициями. Развитие торговой инфраструктуры. Генерирование торговых идей/идей новых...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68003740',
#    'premium': False,
#    'name': 'Стажер DS CV',
#    'department': {'id': '3529-3529-data', 'name': 'Сбер. Data Science'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-20T21:19:32+0300',
#    'created_at': '2022-07-20T21:19:32+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68003740',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68003740?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68003740/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68003740',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт в области компьютерного зрения и нейронках. Знание PyTorch, git. Опыт в linux. Знание FFmpeg, OpenCV. Знание sql. Софт-навыки.',
#     'responsibility': 'Подготовка данных и частей pipeline-а для обучения. Обучение моделей и анализ результатов.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68336006',
#    'premium': False,
#    'name': 'Охранник',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '49',
#     'name': 'Киров (Кировская область)',
#     'url': 'https://api.hh.ru/areas/49'},
#    'salary': {'from': 28000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-01T11:55:12+0300',
#    'created_at': '2022-08-01T11:55:12+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68336006',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68336006?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68336006/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68336006',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Образование полное среднее. Наличие свидетельства, выданного территориальными подразделениями МВД России, о присвоении квалификации частного охранника 6 разряда. Образование не ниже...',
#     'responsibility': 'Работа в составе смены дежурной службы. Осуществление контрольно-пропускного и внутриобъектового режимов (внимательность, тактичность общения с людьми). Умение обращаться с...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68391890',
#    'premium': False,
#    'name': 'Старший клиентский менеджер',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '78', 'name': 'Самара', 'url': 'https://api.hh.ru/areas/78'},
#    'salary': {'from': 57100, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-02T12:57:59+0300',
#    'created_at': '2022-08-02T12:57:59+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68391890',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68391890?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68391890/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68391890',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68102089',
#    'premium': False,
#    'name': 'Старший клиентский менеджер',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '301',
#     'name': 'Обнинск',
#     'url': 'https://api.hh.ru/areas/301'},
#    'salary': {'from': 56000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Обнинск',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 55.0943144,
#     'lng': 36.6121639,
#     'raw': 'Обнинск',
#     'metro': None,
#     'metro_stations': [],
#     'id': '6833149'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-25T10:33:01+0300',
#    'created_at': '2022-07-25T10:33:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68102089',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68102089?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68102089/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68102089',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68511069',
#    'premium': False,
#    'name': 'Специалист по экономической безопасности',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '95', 'name': 'Тюмень', 'url': 'https://api.hh.ru/areas/95'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-05T12:11:36+0300',
#    'created_at': '2022-08-05T12:11:36+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68511069',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68511069?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68511069/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68511069',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (экономика/юриспруденция). Опыт работы по направлению экономической безопасности от 3х лет, наличие опыта работы в правоохранительных органах...',
#     'responsibility': 'Проверкой контрагентов на предмет наличия негативной информации в отношении деятельности и деловой репутации заемщиков, участников сделки, закупочных процедур, ТСТ в...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68674125',
#    'premium': False,
#    'name': 'Мастер по маникюру',
#    'department': {'id': '3529-3529-clients',
#     'name': 'Сбер. Работа с клиентами'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '66',
#     'name': 'Нижний Новгород',
#     'url': 'https://api.hh.ru/areas/66'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Нижний Новгород',
#     'street': 'Октябрьская улица',
#     'building': '35',
#     'description': None,
#     'lat': 56.322075,
#     'lng': 44.009966,
#     'raw': 'Нижний Новгород, Октябрьская улица, 35',
#     'metro': {'station_name': 'Горьковская',
#      'line_name': 'Автозаводская',
#      'station_id': '50.278',
#      'line_id': '50',
#      'lat': 56.313933,
#      'lng': 43.99482},
#     'metro_stations': [{'station_name': 'Горьковская',
#       'line_name': 'Автозаводская',
#       'station_id': '50.278',
#       'line_id': '50',
#       'lat': 56.313933,
#       'lng': 43.99482}],
#     'id': '168974'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-11T09:10:24+0300',
#    'created_at': '2022-08-11T09:10:24+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68674125',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68674125?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68674125/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68674125',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы не менее 1 года. Пунктуальность , тактичность, доброжелательность. Наличие портфолио (фотографии работ). Наличие мед. книжки. Расходные материалы мастера должны...',
#     'responsibility': 'Качественное выполнение маникюра/педикюра с покрытием гель-лак. Выравнивание ногтевой пластины. Покрытие под кутикулу. Владение техникой комбинированного/аппаратного маникюра. '},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#      'name': 'Можно работать сменами по\xa04–6 часов в\xa0день'}],
#    'working_time_modes': [{'id': 'start_after_sixteen',
#      'name': 'Можно начинать работать после 16:00'}],
#    'accept_temporary': False},
#   {'id': '68238612',
#    'premium': False,
#    'name': 'Главный экономист Департамента финансов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-28T12:40:45+0300',
#    'created_at': '2022-07-28T12:40:45+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68238612',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68238612?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68238612/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68238612',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее финансово-экономическое и/или техническое (математическое) образование (МГУ, НИУ ВШЭ и т.п.). Опыт автоматизации финансовой отчетности. ',
#     'responsibility': 'Участие в процессе подготовки управленческой отчетности блока «Розничный бизнес» (РБ). Участие в согласовании проектов РБ, запуска новых каналов, продуктов. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68408984',
#    'premium': False,
#    'name': 'Старший клиентский менеджер',
#    'department': {'id': '3529-3529-clients',
#     'name': 'Сбер. Работа с клиентами'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '71', 'name': 'Пенза', 'url': 'https://api.hh.ru/areas/71'},
#    'salary': {'from': 47400, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Пенза',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 53.1753314,
#     'lng': 45.0348625,
#     'raw': 'Пенза',
#     'metro': None,
#     'metro_stations': [],
#     'id': '7455067'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-02T17:52:35+0300',
#    'created_at': '2022-08-02T17:52:35+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68408984',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68408984?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68408984/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68408984',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68602959',
#    'premium': False,
#    'name': 'Андеррайтер (малый и микро бизнес)',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '26',
#     'name': 'Воронеж',
#     'url': 'https://api.hh.ru/areas/26'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-09T11:55:57+0300',
#    'created_at': '2022-08-09T11:55:57+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68602959',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68602959?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68602959/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68602959',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Образование высшее экономическое/техническое. Опыт работы не менее 1-го года в банковской сфере /финансовых структурах. Знания бухгалтерского учет предприятий...',
#     'responsibility': 'Проводит независимую экспертизу рисков, формирует заключения по итогам анализа полученного пакета документов и принятие решений о предоставлении/отказе в предоставлении...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68286522',
#    'premium': False,
#    'name': 'Старший менеджер по обслуживанию',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1425',
#     'name': 'Буйнакск',
#     'url': 'https://api.hh.ru/areas/1425'},
#    'salary': {'from': 38300, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Буйнакск',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 42.8214424,
#     'lng': 47.1165263,
#     'raw': 'Буйнакск',
#     'metro': None,
#     'metro_stations': [],
#     'id': '7647995'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-29T14:23:53+0300',
#    'created_at': '2022-07-29T14:23:53+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68286522',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68286522?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68286522/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68286522',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Владеешь программами Microsoft Office, Outlook. Готов к работе, предполагающей ежедневное проведение...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Осуществлять операции по обслуживанию клиентов. Проводить кассовые операции: прием, выдача, обмен денег. Предлагать продукты и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67233281',
#    'premium': False,
#    'name': 'Менеджер по ведению партнеров',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32',
#     'description': None,
#     'lat': 55.740421,
#     'lng': 37.532071,
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'МЦК',
#      'station_id': '95.536',
#      'line_id': '95',
#      'lat': 55.740833,
#      'lng': 37.533333},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '823806'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-25T12:16:40+0300',
#    'created_at': '2022-07-25T12:16:40+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67233281',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67233281?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67233281/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67233281',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование. Умение вести переговоры на высоком уровне. Опыт активных продаж на рынке B2B. Отличная осведомленность в науке...',
#     'responsibility': 'Основная задача — ведение партнёрского трека для двух крупнейших молодежных акселераторов России SberZ и SberStudent. Нужно выстраивать долгосрочные отношения с широким...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55221095',
#    'premium': False,
#    'name': 'Старший клиентский менеджер',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '3',
#     'name': 'Екатеринбург',
#     'url': 'https://api.hh.ru/areas/3'},
#    'salary': {'from': 64790, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-12T13:48:16+0300',
#    'created_at': '2022-08-12T13:48:16+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55221095',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55221095?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55221095/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55221095',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и необходимые для них документы. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68772395',
#    'premium': False,
#    'name': 'Frontend-разработчик',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32',
#     'description': None,
#     'lat': 55.740421,
#     'lng': 37.532071,
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'metro': {'station_name': 'Кутузовская',
#      'line_name': 'МЦК',
#      'station_id': '95.536',
#      'line_id': '95',
#      'lat': 55.740833,
#      'lng': 37.533333},
#     'metro_stations': [{'station_name': 'Кутузовская',
#       'line_name': 'МЦК',
#       'station_id': '95.536',
#       'line_id': '95',
#       'lat': 55.740833,
#       'lng': 37.533333}],
#     'id': '823806'},
#    'response_url': None,
#    'sort_point_distance': None,
# ...
#    'adv_response_url': 'https://api.hh.ru/vacancies/67415350/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67415350',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование в сфере финансов или экономики. Опыт работы в сфере продаж инвестиционных продуктов. Опыт работы с автоматизированными банковскими системами. ',
#     'responsibility': 'Мы работаем с биржевыми инструментами, помогаем создавать инвестиционный портфель и используем готовые стратегии для формирования капитала клиентов. Готовить предложения по...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68783145',
#    'premium': False,
#    'name': 'Клиентский менеджер Сбербанк Премьер',
#    'department': {'id': '3529-3529-clients',
#     'name': 'Сбер. Работа с клиентами'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '53',
#     'name': 'Краснодар',
#     'url': 'https://api.hh.ru/areas/53'},
#    'salary': {'from': 70000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-15T12:08:24+0300',
#    'created_at': '2022-08-15T12:08:24+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68783145',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68783145?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68783145/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68783145',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование в сфере финансов или экономики. Опыт работы в сфере продаж инвестиционных продуктов. Опыт работы с автоматизированными банковскими системами. ',
#     'responsibility': 'Готовить предложения по оптимальному набору продуктов и услуг для клиента. Предлагать продукты Сбера. Взаимодействовать с другими подразделениями и партнерами для...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68781376',
#    'premium': False,
#    'name': 'Старший клиентский менеджер',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1140',
#     'name': 'Тулун',
#     'url': 'https://api.hh.ru/areas/1140'},
#    'salary': {'from': 51600, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-15T11:42:49+0300',
#    'created_at': '2022-08-15T11:42:49+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68781376',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68781376?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68781376/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68781376',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и необходимые для них документы. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '67165030',
#    'premium': False,
#    'name': 'Старший специалист по взысканию',
#    'department': {'id': '3529-3529-stat', 'name': 'Сбер. Начало карьеры'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1381',
#     'name': 'Сургут',
#     'url': 'https://api.hh.ru/areas/1381'},
#    'salary': {'from': 120200, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-24T15:27:01+0300',
#    'created_at': '2022-07-24T15:27:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=67165030',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/67165030?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/67165030/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/67165030',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним специальным, неоконченным высшим или высшим образованием. Готов к разъездной работе. Умеешь справляться со стрессом и ориентирован на...',
#     'responsibility': 'Ездить к клиентам по месту жительства или работы. Вести переговоры с клиентами банка с целью возврата просроченной задолженности (лично и...'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68478983',
#    'premium': False,
#    'name': 'Клиентский менеджер малого и микробизнеса',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '68', 'name': 'Омск', 'url': 'https://api.hh.ru/areas/68'},
#    'salary': {'from': 52000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-04T13:41:03+0300',
#    'created_at': '2022-08-04T13:41:03+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68478983',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68478983?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68478983/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68478983',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (финансы/банки, экономика/бухгалтерия). Опыт в сфере продаж или обслуживания клиентов от 1 года. Грамотная и структурированная речь. ',
#     'responsibility': 'Консультировать корпоративных клиентов по продуктам банка и экосистемы. Обслуживать юридические лица при открытии расчётного счета. Формировать потребность клиента на комплексное...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68188564',
#    'premium': False,
#    'name': 'Старший клиентский менеджер',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2028',
#     'name': 'Истра',
#     'url': 'https://api.hh.ru/areas/2028'},
#    'salary': {'from': 86000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Истра',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 55.9061359,
#     'lng': 36.8600924,
#     'raw': 'Истра',
#     'metro': None,
#     'metro_stations': [],
#     'id': '11369282'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-07-27T09:51:38+0300',
#    'created_at': '2022-07-27T09:51:38+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68188564',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68188564?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68188564/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68188564',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68648622',
#    'premium': False,
#    'name': 'Старший клиентский менеджер',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '89', 'name': 'Тверь', 'url': 'https://api.hh.ru/areas/89'},
#    'salary': {'from': 60000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Тверь',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 56.8586059,
#     'lng': 35.9116761,
#     'raw': 'Тверь',
#     'metro': None,
#     'metro_stations': [],
#     'id': '6833153'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-10T13:01:11+0300',
#    'created_at': '2022-08-10T13:01:11+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68648622',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68648622?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68648622/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68648622',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Специалист со средним профессиональным, неполным высшим или высшим образованием. Имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от...',
#     'responsibility': 'Доброжелателен и готов помогать клиентам. Предлагать продукты и услуги Сбера. Консультировать клиентов по возникающим вопросам. Помогать клиентам оформлять услуги и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '68704111',
#    'premium': False,
#    'name': 'Инженер по функциональному тестированию (проект SberTeamID)',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Кутузовский проспект',
#     'building': '32',
#     'description': None,
#     'lat': 55.740426,
#     'lng': 37.532071,
#     'raw': 'Москва, Кутузовский проспект, 32',
#     'metro': None,
#     'metro_stations': [],
#     'id': '6080840'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-08-11T20:33:00+0300',
#    'created_at': '2022-08-11T20:33:00+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=68704111',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/68704111?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/68704111/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/68704111',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Неоконченное или высшее техническое образование. Знание теории тестирования. Знание жизненного цикла программного обеспечения и дефекта. Желателен опыт написания тестовых сценариев. ',
#     'responsibility': 'Всё про жизненный цикл учетных записей: создание, изменение, удаление, выдача прав доступа, блокировка и т.п. Уже есть отдельное веб...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False}],
#  'found': 4534,
#  'pages': 20,
#  'per_page': 100,
#  'page': 1,
#  'clusters': None,
#  'arguments': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?control_flag=vacancyBlacklistJoinEnabled%3ATrue&employer_id=3529&enable_snippets=true&items_on_page=100&page=1'}

# %%
vacancies = res.json()
num_pages = vacancies.get('pages')
vacancy_ids = [el.get('id') for el in vacancies.get('items')]

# %%
vnum  = vacancies.get('pages')

# %%
all_vacancy_ids= []
for i in tqdm(range(vnum)):
    url = f'https://api.hh.ru/vacancies?employer_id={sber}&page={i}&per_page={num_per_page}&area={moscow}'
    res = requests.get(url)
    vacancies = res.json()
    vacancy_ids = [el.get('id') for el in vacancies.get('items')]
    all_vacancy_ids.extend(vacancy_ids)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
vacs = []
for vac_id in tqdm(all_vacancy_ids):
    url = f'https://api.hh.ru/vacancies/{vac_id}'
    res = requests.get(url)
    vacs.append(res.json())
# Out:
#   0%|          | 0/1218 [00:00<?, ?it/s]

# %%
df = pd.json_normalize(vacs)

# %%
df.head()
# Out:
#          id  premium relations  \
# 0  55415805    False        []
# 1  68363939    False        []
# 2  68899553    False        []
# 3  67349462    False        []
# 4  68704654    False        []
#
#                                                 name insider_interview  \
# 0                     Менеджер по работе с клиентами              None
# 1                             Финансовый консультант              None
# 2  Разработчик интерфейсов/frontend разработчик (...              None
# 3                        Старший клиентский менеджер              None
# 4                              Стажер Data scientist              None
#
#    response_letter_required  address  allow_messages contacts  \
# 0                     False      NaN            True     None
# 1                     False      NaN            True     None
# 2                     False      NaN            True     None
# 3                     False      NaN            True     None
# 4                     False      NaN            True     None
#
#                                          description  ...  \
# 0  <p>Сбер — лучший работодатель России. У нас бо...  ...
# 1  <p>Сбер — лучший работодатель России. У нас бо...  ...
# 2  <p>В команду SberDevices ищем стажера JS. Мы н...  ...
# 3  <p>Сбер — лучший работодатель России. У нас бо...  ...
# 4  <p>Блок &quot;Сеть продаж&quot; курирует все ф...  ...
#
#   address.metro.station_id address.metro.line_id address.metro.lat  \
# 0                      NaN                   NaN               NaN
# 1                     3.47                     3         55.743117
# 2                   95.536                    95         55.740833
# 3                      NaN                   NaN               NaN
# 4                     4.73                     4         55.740544
#
#    address.metro.lng                             address.metro_stations  \
# 0                NaN                                                NaN
# 1          37.564132  [{'station_name': 'Киевская', 'line_name': 'Ар...
# 2          37.533333  [{'station_name': 'Кутузовская', 'line_name': ...
# 3                NaN                                                NaN
# 4          37.534100  [{'station_name': 'Кутузовская', 'line_name': ...
#
#    salary department test.required address.metro immediate_redirect_url
# 0     NaN        NaN           NaN           NaN                    NaN
# 1     NaN        NaN           NaN           NaN                    NaN
# 2     NaN        NaN           NaN           NaN                    NaN
# 3     NaN        NaN           NaN           NaN                    NaN
# 4     NaN        NaN           NaN           NaN                    NaN
#
# [5 rows x 85 columns]

# %%
df_hh = df

# %%
df_hh
# Out:
#             id  premium relations  \
# 0     55415805    False        []
# 1     68363939    False        []
# 2     68899553    False        []
# 3     67349462    False        []
# 4     68704654    False        []
# ...        ...      ...       ...
# 1213  68787346     True        []
# 1214  67799534     True        []
# 1215  67799754     True        []
# 1216  67799537     True        []
# 1217  67799535     True        []
#
#                                                    name insider_interview  \
# 0                        Менеджер по работе с клиентами              None
# 1                                Финансовый консультант              None
# 2     Разработчик интерфейсов/frontend разработчик (...              None
# 3                           Старший клиентский менеджер              None
# 4                                 Стажер Data scientist              None
# ...                                                 ...               ...
# 1213                        Старший клиентский менеджер              None
# 1214                  Клиентский менеджер прямых продаж              None
# 1215                     Менеджер по работе с клиентами              None
# 1216                  Клиентский менеджер прямых продаж              None
# 1217                  Клиентский менеджер прямых продаж              None
#
#       response_letter_required  address  allow_messages contacts  \
# 0                        False      NaN            True     None
# 1                        False      NaN            True     None
# 2                        False      NaN            True     None
# 3                        False      NaN            True     None
# 4                        False      NaN            True     None
# ...                        ...      ...             ...      ...
# 1213                     False      NaN            True     None
# 1214                     False      NaN           False     None
# 1215                     False      NaN            True     None
# 1216                     False      NaN            True     None
# 1217                     False      NaN           False     None
#
#                                             description  ...  \
# 0     <p>Сбер — лучший работодатель России. У нас бо...  ...
# 1     <p>Сбер — лучший работодатель России. У нас бо...  ...
# 2     <p>В команду SberDevices ищем стажера JS. Мы н...  ...
# 3     <p>Сбер — лучший работодатель России. У нас бо...  ...
# 4     <p>Блок &quot;Сеть продаж&quot; курирует все ф...  ...
# ...                                                 ...  ...
# 1213  <p>Сбер — лучший работодатель России. У нас бо...  ...
# 1214  <p>Сбер — лучший работодатель России. У нас бо...  ...
# 1215  <p>Сбер — лучший работодатель России. У нас бо...  ...
# 1216  <p>Сбер — лучший работодатель России. У нас бо...  ...
# 1217  <p>Сбер — лучший работодатель России. У нас бо...  ...
#
#      address.metro.station_id address.metro.line_id address.metro.lat  \
# 0                         NaN                   NaN               NaN
# 1                        3.47                     3         55.743117
# 2                      95.536                    95         55.740833
# 3                         NaN                   NaN               NaN
# 4                        4.73                     4         55.740544
# ...                       ...                   ...               ...
# 1213                      NaN                   NaN               NaN
# 1214                      NaN                   NaN               NaN
# 1215                      NaN                   NaN               NaN
# 1216                      NaN                   NaN               NaN
# 1217                      NaN                   NaN               NaN
#
#       address.metro.lng                             address.metro_stations  \
# 0                   NaN                                                NaN
# 1             37.564132  [{'station_name': 'Киевская', 'line_name': 'Ар...
# 2             37.533333  [{'station_name': 'Кутузовская', 'line_name': ...
# 3                   NaN                                                NaN
# 4             37.534100  [{'station_name': 'Кутузовская', 'line_name': ...
# ...                 ...                                                ...
# 1213                NaN                                                NaN
# 1214                NaN                                                NaN
# 1215                NaN                                                NaN
# 1216                NaN                                                NaN
# 1217                NaN                                                NaN
#
#       salary department test.required address.metro  \
# 0        NaN        NaN           NaN           NaN
# 1        NaN        NaN           NaN           NaN
# 2        NaN        NaN           NaN           NaN
# 3        NaN        NaN           NaN           NaN
# 4        NaN        NaN           NaN           NaN
# ...      ...        ...           ...           ...
# 1213     NaN        NaN           NaN           NaN
# 1214     NaN        NaN           NaN           NaN
# 1215     NaN        NaN           NaN           NaN
# 1216     NaN        NaN           NaN           NaN
# 1217     NaN        NaN           NaN           NaN
#
#               immediate_redirect_url
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 1213  https://hh.ru/vacancy/67500653
# 1214  https://hh.ru/vacancy/67264564
# 1215  https://hh.ru/vacancy/67598772
# 1216  https://hh.ru/vacancy/67264148
# 1217  https://hh.ru/vacancy/67264345
#
# [1218 rows x 85 columns]

# %%
df_hh['description_len'] = df_hh.description.apply(lambda x:len(x))
pd.options.display.max_colwidth = max(df_hh['description_len'])
df_hh['description'] = df_hh.description.apply(lambda y: y.replace('<p>', '').replace('</p>', '').replace('<strong>', '').replace('</strong>', '').replace('<ul>', '').replace('<li>', '').replace('</li>', '').replace('</ul>', ''))
df_hh
# Out:
#             id  premium relations  \
# 0     55415805    False        []
# 1     68363939    False        []
# 2     68899553    False        []
# 3     67349462    False        []
# 4     68704654    False        []
# ...        ...      ...       ...
# 1213  68787346     True        []
# 1214  67799534     True        []
# 1215  67799754     True        []
# 1216  67799537     True        []
# 1217  67799535     True        []
#
#                                                                      name  \
# 0                                          Менеджер по работе с клиентами
# 1                                                  Финансовый консультант
# 2     Разработчик интерфейсов/frontend разработчик (стажер) в SberDevices
# 3                                             Старший клиентский менеджер
# 4                                                   Стажер Data scientist
# ...                                                                   ...
# 1213                                          Старший клиентский менеджер
# 1214                                    Клиентский менеджер прямых продаж
# 1215                                       Менеджер по работе с клиентами
# 1216                                    Клиентский менеджер прямых продаж
# 1217                                    Клиентский менеджер прямых продаж
#
#      insider_interview  response_letter_required  address  allow_messages  \
# 0                 None                     False      NaN            True
# 1                 None                     False      NaN            True
# 2                 None                     False      NaN            True
# 3                 None                     False      NaN            True
# 4                 None                     False      NaN            True
# ...                ...                       ...      ...             ...
# 1213              None                     False      NaN            True
# 1214              None                     False      NaN           False
# 1215              None                     False      NaN            True
# 1216              None                     False      NaN            True
# 1217              None                     False      NaN           False
#
#      contacts  \
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# ...       ...
# 1213     None
# 1214     None
# 1215     None
# 1216     None
# 1217     None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. Сбер ищет клиентского менеджера для работы в мобильных офисах. Это специалист, который консультирует клиентов по продуктам, услугам и сервисам Сбера в торговых центрах, аэропортах и гипермаркетах. Эта работа для активных и общительных людей, которые стремятся к карьере и финансовому достатку. Ты подходишь нам, если ты готов:  продавать банковские продукты и сервисы в мобильных офисах Сбера: торговых центрах, магазинах, гипермаркетах, аэропортах рассказывать клиентам о преимуществах сервисов Сбера и экосистемы помогать клиентам оформлять продукты и услуги Сбера.  Опыт работы консультантом или промоутером приветствуется. Работа в Сбере – это:  стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня гибкий график работы, можно совмещать с учебой мобильная связь и корпоративный ipad оплата транспортных расходов корпоративная пенсионная программа расширенный ДМС с первого дня и льготное страхование для близких бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративное обучение в Виртуальной школе Сбера  ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде клиентских менеджеров Сбера!
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. При оформлении карт Сбера через приложение, клиент может выбрать доставку в удобное место и время. Финансовый консультант развозит банковские продукты Сбера клиентам, а при встрече предлагает дополнительные услуги или сервисы и помогает с их оформлением. Эта работа для тех, кому интересно развиваться в банковской сфере и привлекает работа вне офиса. Тебе предстоит:  встречаться с 7-15 клиентами в день для выдачи банковских карт по удобному для клиента адресу перемещаться по городу в течение дня продавать клиенту на встрече дополнительные продукты и услуги Сбера.  Работа в Сбере – это:  стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня возможность выбрать удобный график расширенный ДМС с первого дня и льготное страхование для близких корпоративный ipad оплата транспортных расходов и мобильной связи теплая база клиентов корпоративное обучение в Виртуальной школе Сбера бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративная пенсионная программа ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде финансовых консультантов Сбера!
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                   В команду SberDevices ищем стажера JS. Мы новое технологическое подразделение, которое занимается разработками в сферах: распознавания и синтеза речи, умных устройств и распознавания жестов. Machine Learning, ИИ и нейронные сети для нас не пустые слова, а инструменты для решения ежедневных задач. Такому умному бэкенду нужен такой же умный интерфейс. В команде разработки интерфейсов SberDevices лучшие специалисты рынка с опытом работы в лучших компаниях России и СНГ. Мы постоянно работаем над качеством наших продуктов и кода, пишем инструменты для инфраструктуры и разработки. Если дух стартапа тебе близок, а сложные задачи — это то, что ты так долго искал, то мы ждем тебя. Чем предстоит заниматься:  разработкой интерфейсных компонентов (инфраструктура и веб-интерфейсы); разработкой клиентской логики на JS; разработкой библиотек для внутренних и внешних команд оптимизацией производительности разработкой инструментов сборки, деплоя и других утилит на JS; визуализацией данных, дизайн, верстка; работой над прототипами и интерфейсами для внутренних аналитических инструментов  Что важно для нас:  базовое знание JavaScript, HTML и CSS; будут плюсом знания React и Typescript  Что мы предлагаем:  работу в команде профессионалов, возможность получить опыт в уникальных и крупных проектах масштаба нашей страны; большой и комфортный офис со спортзалом, библиотекой, столами для пинг-понга, кафе для сотрудников и видом на Москва Сити;
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. Мы ищем старшего менеджера по сопровождению клиентов. Его главная задача – помогать клиентам с оформлением продуктов и услуг Сбера и экосистемы, а также консультировать по возникающим вопросам. Эта вакансия для тех, кто хочет развивать навыки эффективных продаж и стоить карьеру в банковской сфере. Эта работа подойдет тебе если ты: · специалист со средним профессиональным, неполным высшим или высшим образованием · имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от 6 месяцев · доброжелателен и готов помогать клиентам.   Тебе предстоит:   · предлагать продукты и услуги Сбера · консультировать клиентов по возникающим вопросам · помогать клиентам оформлять услуги и необходимые для них документы · совершать транзакционные операции в рамках оформления продаж и постпродажного сопровождения клиентов · вести базы клиентов.   Работа в Сбере – это:  · стабильный оклад и социальная поддержка сотрудников · официальное оформление с первого дня · расширенный ДМС с первого дня и льготное страхование для близких · корпоративное обучение в Виртуальной школе Сбера · бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров · корпоративная пенсионная программа · ипотека выгоднее на 4% для каждого сотрудника.   Присоединяйся к команде старших клиентских менеджеров Сбера!
# 4     Блок &quot;Сеть продаж&quot; курирует все физические каналы касания клиента с экосистемой (отделения, банкоматы, агентская сеть и тд). Мы разрабатываем и внедряем end-to-end решения на основе машинного обучения в бизнес-процессы, связанные с обслуживанием клиентов. &quot;Поток продаж&quot; представляет собой автоматизированную систему по доставке персональных предложений для клиентов. Вместе мы будем создавать новые процессы и разрабатывать приложения. Сейчас мы в поиске стажера на вакансию Стажер Data scientist в команду управления моделированием и исследованием данных.   Обязанности:  Самостоятельное ведение проекта под руководством baddy (senior data scientist) Обучение и проверка pull request Реализация распознавания документов на готовом решении Сбера Анализ неструктурированной информации (презентации, документы) Проверка гипотез с помощью методов машинного обучения  Требования:  Высшее образование/не законченное высшее (ИТ/техническое/математическое/экономико-математическое) Основы SQL Знание основных алгоритмов интеллектуального анализа данных Python в качестве основного языка Знание основных алгоритмов интеллектуального анализа данных (линейная/логистическая регрессия, random forest, xgboost и т.д.) Парсинг данных из открытых источников как дополнительное преимущество Умение работать в команде  Условия:  Дружная разносторонняя команда Уникальные масштабные проекты и сложные разноплановые задачи. Участие в различных конференциях, митапах банка и корпоративных мероприятиях. Обучение за счёт банка (онлайн и офлайн, в т. ч. на внешних платформах). Оформление по ТК на 6 месяцев на ставку стажера. В случае успешного прохождения стажировки, перевод на постоянную должность. ДМС, спортзал, сниженные ставки по кредитам, дисконт-программы от множества компаний-партнеров. Возможность принять участие в других крупных и уникальных проектах банка.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 1213                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. Мы ищем старшего менеджера по сопровождению клиентов. Его главная задача – помогать клиентам с оформлением продуктов и услуг Сбера и экосистемы, а также консультировать по возникающим вопросам. Эта вакансия для тех, кто хочет развивать навыки эффективных продаж и стоить карьеру в банковской сфере. Эта работа подойдет тебе если ты: · специалист со средним профессиональным, неполным высшим или высшим образованием · имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от 6 месяцев · доброжелателен и готов помогать клиентам. Тебе предстоит: · предлагать продукты и услуги Сбера · консультировать клиентов по возникающим вопросам · помогать клиентам оформлять услуги и необходимые для них документы · совершать транзакционные операции в рамках оформления продаж и постпродажного сопровождения клиентов · вести базы клиентов. Работа в Сбере – это: · стабильный оклад и социальная поддержка сотрудников · официальное оформление с первого дня · расширенный ДМС с первого дня и льготное страхование для близких · корпоративное обучение в Виртуальной школе Сбера · бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров · корпоративная пенсионная программа · ипотека выгоднее на 4% для каждого сотрудника. Присоединяйся к команде старших клиентских менеджеров Сбера!
# 1214                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. У каждого нашего зарплатного клиента – компаний партнеров — есть свой эксперт по финансовым вопросам. Он приезжает в офисы партнеров банка несколько раз в неделю, презентует наши продукты, консультирует сотрудников компании по продуктам и сервисам, а также помогает с их оформлением.<br />Это работа для тех, кому интересны сфера продаж, развитие навыков убеждения, личных переговоров и выступлений. А также привлекает работа вне офиса. Тебе предстоит:  выезжать к клиентам на индивидуальные консультации проводить презентации сервисов Сбера на территории компаний-партнеров предлагать сервисы Сбера и помогать с их оформлением.  Работа в Сбере – это:   стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня расширенный ДМС с первого дня и льготное страхование для близких мобильная связь, корпоративный ipad оплата транспортных расходов теплая база клиентов корпоративное обучение в Виртуальной школе Сбера бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративная пенсионная программа ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде клиентских менеджеров Сбера!
# 1215                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. Сбер ищет клиентского менеджера для работы в мобильных офисах. Это специалист, который консультирует клиентов по продуктам, услугам и сервисам Сбера в торговых центрах, аэропортах и гипермаркетах. Эта работа для активных и общительных людей, которые стремятся к карьере и финансовому достатку. Ты подходишь нам, если ты готов:  продавать банковские продукты и сервисы в мобильных офисах Сбера: торговых центрах, магазинах, гипермаркетах, аэропортах рассказывать клиентам о преимуществах сервисов Сбера и экосистемы помогать клиентам оформлять продукты и услуги Сбера.  Опыт работы консультантом или промоутером приветствуется. Работа в Сбере – это:  стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня гибкий график работы, можно совмещать с учебой мобильная связь и корпоративный ipad оплата транспортных расходов корпоративная пенсионная программа расширенный ДМС с первого дня и льготное страхование для близких бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративное обучение в Виртуальной школе Сбера ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде клиентских менеджеров Сбера!
# 1216                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. У каждого нашего зарплатного клиента – компаний партнеров — есть свой эксперт по финансовым вопросам. Он приезжает в офисы партнеров банка несколько раз в неделю, презентует наши продукты, консультирует сотрудников компании по продуктам и сервисам, а также помогает с их оформлением.<br />Это работа для тех, кому интересны сфера продаж, развитие навыков убеждения, личных переговоров и выступлений. А также привлекает работа вне офиса. Тебе предстоит:  выезжать к клиентам на индивидуальные консультации проводить презентации сервисов Сбера на территории компаний-партнеров предлагать сервисы Сбера и помогать с их оформлением.  Работа в Сбере – это:   стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня расширенный ДМС с первого дня и льготное страхование для близких мобильная связь, корпоративный ipad оплата транспортных расходов теплая база клиентов корпоративное обучение в Виртуальной школе Сбера бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративная пенсионная программа ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде клиентских менеджеров Сбера!
# 1217                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. У каждого нашего зарплатного клиента – компаний партнеров — есть свой эксперт по финансовым вопросам. Он приезжает в офисы партнеров банка несколько раз в неделю, презентует наши продукты, консультирует сотрудников компании по продуктам и сервисам, а также помогает с их оформлением.<br />Это работа для тех, кому интересны сфера продаж, развитие навыков убеждения, личных переговоров и выступлений. А также привлекает работа вне офиса. Тебе предстоит:  выезжать к клиентам на индивидуальные консультации проводить презентации сервисов Сбера на территории компаний-партнеров предлагать сервисы Сбера и помогать с их оформлением.  Работа в Сбере – это:   стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня расширенный ДМС с первого дня и льготное страхование для близких мобильная связь, корпоративный ipad оплата транспортных расходов теплая база клиентов корпоративное обучение в Виртуальной школе Сбера бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративная пенсионная программа ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде клиентских менеджеров Сбера!
#
#       ... address.metro.line_id address.metro.lat address.metro.lng  \
# 0     ...                   NaN               NaN               NaN
# 1     ...                     3         55.743117         37.564132
# 2     ...                    95         55.740833         37.533333
# 3     ...                   NaN               NaN               NaN
# 4     ...                     4         55.740544         37.534100
# ...   ...                   ...               ...               ...
# 1213  ...                   NaN               NaN               NaN
# 1214  ...                   NaN               NaN               NaN
# 1215  ...                   NaN               NaN               NaN
# 1216  ...                   NaN               NaN               NaN
# 1217  ...                   NaN               NaN               NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                               address.metro_stations  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# 1     [{'station_name': 'Киевская', 'line_name': 'Арбатско-Покровская', 'station_id': '3.47', 'line_id': '3', 'lat': 55.743117, 'lng': 37.564132}, {'station_name': 'Киевская', 'line_name': 'Филевская', 'station_id': '4.48', 'line_id': '4', 'lat': 55.743168, 'lng': 37.565425}, {'station_name': 'Киевская', 'line_name': 'Кольцевая', 'station_id': '5.49', 'line_id': '5', 'lat': 55.74361, 'lng': 37.56735}]
# 2                                                                                                                                                                                                                                                                                 [{'station_name': 'Кутузовская', 'line_name': 'МЦК', 'station_id': '95.536', 'line_id': '95', 'lat': 55.740833, 'lng': 37.533333}]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# 4                                                                                                                                              [{'station_name': 'Кутузовская', 'line_name': 'Филевская', 'station_id': '4.73', 'line_id': '4', 'lat': 55.740544, 'lng': 37.5341}, {'station_name': 'Кутузовская', 'line_name': 'МЦК', 'station_id': '95.536', 'line_id': '95', 'lat': 55.740833, 'lng': 37.533333}]
# ...                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 1213                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 1214                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 1215                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 1216                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 1217                                                                                                                                                                                                                                                                                                                                                                                                             NaN
#
#       salary  department test.required address.metro  \
# 0        NaN         NaN           NaN           NaN
# 1        NaN         NaN           NaN           NaN
# 2        NaN         NaN           NaN           NaN
# 3        NaN         NaN           NaN           NaN
# 4        NaN         NaN           NaN           NaN
# ...      ...         ...           ...           ...
# 1213     NaN         NaN           NaN           NaN
# 1214     NaN         NaN           NaN           NaN
# 1215     NaN         NaN           NaN           NaN
# 1216     NaN         NaN           NaN           NaN
# 1217     NaN         NaN           NaN           NaN
#
#               immediate_redirect_url description_len
# 0                                NaN            1511
# 1                                NaN            1467
# 2                                NaN            1604
# 3                                NaN            1663
# 4                                NaN            2191
# ...                              ...             ...
# 1213  https://hh.ru/vacancy/67500653            1626
# 1214  https://hh.ru/vacancy/67264564            1480
# 1215  https://hh.ru/vacancy/67598772            1510
# 1216  https://hh.ru/vacancy/67264148            1480
# 1217  https://hh.ru/vacancy/67264345            1480
#
# [1218 rows x 86 columns]

# %%
df_hh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 86 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            1218 non-null   object
#  1   premium                       1218 non-null   bool
#  2   relations                     1218 non-null   object
#  3   name                          1218 non-null   object
#  4   insider_interview             0 non-null      object
#  5   response_letter_required      1218 non-null   bool
#  6   address                       0 non-null      float64
#  7   allow_messages                1218 non-null   bool
#  8   contacts                      0 non-null      object
#  9   description                   1218 non-null   object
#  10  branded_description           975 non-null    object
#  11  vacancy_constructor_template  0 non-null      object
#  12  key_skills                    1218 non-null   object
#  13  accept_handicapped            1218 non-null   bool
#  14  accept_kids                   1218 non-null   bool
#  15  archived                      1218 non-null   bool
#  16  response_url                  18 non-null     object
#  17  specializations               1218 non-null   object
#  18  professional_roles            1218 non-null   object
#  19  code                          18 non-null     object
#  20  hidden                        1218 non-null   bool
#  21  quick_responses_allowed       1218 non-null   bool
#  22  driver_license_types          1218 non-null   object
#  23  accept_incomplete_resumes     1218 non-null   bool
#  24  published_at                  1218 non-null   object
#  25  created_at                    1218 non-null   object
#  26  initial_created_at            1218 non-null   object
#  27  negotiations_url              0 non-null      object
#  28  suitable_resumes_url          0 non-null      object
#  29  apply_alternate_url           1218 non-null   object
#  30  has_test                      1218 non-null   bool
#  31  test                          0 non-null      float64
#  32  alternate_url                 1218 non-null   object
#  33  working_days                  1218 non-null   object
#  34  working_time_intervals        1218 non-null   object
#  35  working_time_modes            1218 non-null   object
#  36  accept_temporary              1218 non-null   bool
#  37  languages                     1218 non-null   object
#  38  billing_type.id               1218 non-null   object
#  39  billing_type.name             1218 non-null   object
#  40  area.id                       1218 non-null   object
#  41  area.name                     1218 non-null   object
#  42  area.url                      1218 non-null   object
#  43  salary.from                   99 non-null     float64
#  44  salary.to                     40 non-null     float64
#  45  salary.currency               107 non-null    object
#  46  salary.gross                  107 non-null    object
#  47  type.id                       1218 non-null   object
#  48  type.name                     1218 non-null   object
#  49  experience.id                 1218 non-null   object
#  50  experience.name               1218 non-null   object
#  51  schedule.id                   1218 non-null   object
#  52  schedule.name                 1218 non-null   object
#  53  employment.id                 1218 non-null   object
#  54  employment.name               1218 non-null   object
#  55  department.id                 1169 non-null   object
#  56  department.name               1169 non-null   object
#  57  employer.id                   1218 non-null   object
#  58  employer.name                 1218 non-null   object
#  59  employer.url                  1218 non-null   object
#  60  employer.alternate_url        1218 non-null   object
#  61  employer.logo_urls.original   1218 non-null   object
#  62  employer.logo_urls.90         1218 non-null   object
#  63  employer.logo_urls.240        1218 non-null   object
#  64  employer.vacancies_url        1218 non-null   object
#  65  employer.trusted              1218 non-null   bool
#  66  address.city                  418 non-null    object
#  67  address.street                408 non-null    object
#  68  address.building              404 non-null    object
#  69  address.description           0 non-null      float64
#  70  address.lat                   418 non-null    float64
#  71  address.lng                   418 non-null    float64
#  72  address.raw                   418 non-null    object
#  73  address.metro.station_name    378 non-null    object
#  74  address.metro.line_name       378 non-null    object
#  75  address.metro.station_id      378 non-null    object
#  76  address.metro.line_id         378 non-null    object
#  77  address.metro.lat             378 non-null    float64
#  78  address.metro.lng             378 non-null    float64
#  79  address.metro_stations        441 non-null    object
#  80  salary                        0 non-null      float64
#  81  department                    0 non-null      float64
#  82  test.required                 2 non-null      object
#  83  address.metro                 0 non-null      float64
#  84  immediate_redirect_url        18 non-null     object
#  85  description_len               1218 non-null   int64
# dtypes: bool(12), float64(12), int64(1), object(61)
# memory usage: 718.6+ KB

# %%
df_hh[['id', 'name', 'description']]
# Out:
#             id  \
# 0     55415805
# 1     68363939
# 2     68899553
# 3     67349462
# 4     68704654
# ...        ...
# 1213  68787346
# 1214  67799534
# 1215  67799754
# 1216  67799537
# 1217  67799535
#
#                                                                      name  \
# 0                                          Менеджер по работе с клиентами
# 1                                                  Финансовый консультант
# 2     Разработчик интерфейсов/frontend разработчик (стажер) в SberDevices
# 3                                             Старший клиентский менеджер
# 4                                                   Стажер Data scientist
# ...                                                                   ...
# 1213                                          Старший клиентский менеджер
# 1214                                    Клиентский менеджер прямых продаж
# 1215                                       Менеджер по работе с клиентами
# 1216                                    Клиентский менеджер прямых продаж
# 1217                                    Клиентский менеджер прямых продаж
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             description
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. Сбер ищет клиентского менеджера для работы в мобильных офисах. Это специалист, который консультирует клиентов по продуктам, услугам и сервисам Сбера в торговых центрах, аэропортах и гипермаркетах. Эта работа для активных и общительных людей, которые стремятся к карьере и финансовому достатку. Ты подходишь нам, если ты готов:  продавать банковские продукты и сервисы в мобильных офисах Сбера: торговых центрах, магазинах, гипермаркетах, аэропортах рассказывать клиентам о преимуществах сервисов Сбера и экосистемы помогать клиентам оформлять продукты и услуги Сбера.  Опыт работы консультантом или промоутером приветствуется. Работа в Сбере – это:  стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня гибкий график работы, можно совмещать с учебой мобильная связь и корпоративный ipad оплата транспортных расходов корпоративная пенсионная программа расширенный ДМС с первого дня и льготное страхование для близких бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративное обучение в Виртуальной школе Сбера  ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде клиентских менеджеров Сбера!
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. При оформлении карт Сбера через приложение, клиент может выбрать доставку в удобное место и время. Финансовый консультант развозит банковские продукты Сбера клиентам, а при встрече предлагает дополнительные услуги или сервисы и помогает с их оформлением. Эта работа для тех, кому интересно развиваться в банковской сфере и привлекает работа вне офиса. Тебе предстоит:  встречаться с 7-15 клиентами в день для выдачи банковских карт по удобному для клиента адресу перемещаться по городу в течение дня продавать клиенту на встрече дополнительные продукты и услуги Сбера.  Работа в Сбере – это:  стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня возможность выбрать удобный график расширенный ДМС с первого дня и льготное страхование для близких корпоративный ipad оплата транспортных расходов и мобильной связи теплая база клиентов корпоративное обучение в Виртуальной школе Сбера бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративная пенсионная программа ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде финансовых консультантов Сбера!
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                   В команду SberDevices ищем стажера JS. Мы новое технологическое подразделение, которое занимается разработками в сферах: распознавания и синтеза речи, умных устройств и распознавания жестов. Machine Learning, ИИ и нейронные сети для нас не пустые слова, а инструменты для решения ежедневных задач. Такому умному бэкенду нужен такой же умный интерфейс. В команде разработки интерфейсов SberDevices лучшие специалисты рынка с опытом работы в лучших компаниях России и СНГ. Мы постоянно работаем над качеством наших продуктов и кода, пишем инструменты для инфраструктуры и разработки. Если дух стартапа тебе близок, а сложные задачи — это то, что ты так долго искал, то мы ждем тебя. Чем предстоит заниматься:  разработкой интерфейсных компонентов (инфраструктура и веб-интерфейсы); разработкой клиентской логики на JS; разработкой библиотек для внутренних и внешних команд оптимизацией производительности разработкой инструментов сборки, деплоя и других утилит на JS; визуализацией данных, дизайн, верстка; работой над прототипами и интерфейсами для внутренних аналитических инструментов  Что важно для нас:  базовое знание JavaScript, HTML и CSS; будут плюсом знания React и Typescript  Что мы предлагаем:  работу в команде профессионалов, возможность получить опыт в уникальных и крупных проектах масштаба нашей страны; большой и комфортный офис со спортзалом, библиотекой, столами для пинг-понга, кафе для сотрудников и видом на Москва Сити;
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. Мы ищем старшего менеджера по сопровождению клиентов. Его главная задача – помогать клиентам с оформлением продуктов и услуг Сбера и экосистемы, а также консультировать по возникающим вопросам. Эта вакансия для тех, кто хочет развивать навыки эффективных продаж и стоить карьеру в банковской сфере. Эта работа подойдет тебе если ты: · специалист со средним профессиональным, неполным высшим или высшим образованием · имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от 6 месяцев · доброжелателен и готов помогать клиентам.   Тебе предстоит:   · предлагать продукты и услуги Сбера · консультировать клиентов по возникающим вопросам · помогать клиентам оформлять услуги и необходимые для них документы · совершать транзакционные операции в рамках оформления продаж и постпродажного сопровождения клиентов · вести базы клиентов.   Работа в Сбере – это:  · стабильный оклад и социальная поддержка сотрудников · официальное оформление с первого дня · расширенный ДМС с первого дня и льготное страхование для близких · корпоративное обучение в Виртуальной школе Сбера · бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров · корпоративная пенсионная программа · ипотека выгоднее на 4% для каждого сотрудника.   Присоединяйся к команде старших клиентских менеджеров Сбера!
# 4     Блок &quot;Сеть продаж&quot; курирует все физические каналы касания клиента с экосистемой (отделения, банкоматы, агентская сеть и тд). Мы разрабатываем и внедряем end-to-end решения на основе машинного обучения в бизнес-процессы, связанные с обслуживанием клиентов. &quot;Поток продаж&quot; представляет собой автоматизированную систему по доставке персональных предложений для клиентов. Вместе мы будем создавать новые процессы и разрабатывать приложения. Сейчас мы в поиске стажера на вакансию Стажер Data scientist в команду управления моделированием и исследованием данных.   Обязанности:  Самостоятельное ведение проекта под руководством baddy (senior data scientist) Обучение и проверка pull request Реализация распознавания документов на готовом решении Сбера Анализ неструктурированной информации (презентации, документы) Проверка гипотез с помощью методов машинного обучения  Требования:  Высшее образование/не законченное высшее (ИТ/техническое/математическое/экономико-математическое) Основы SQL Знание основных алгоритмов интеллектуального анализа данных Python в качестве основного языка Знание основных алгоритмов интеллектуального анализа данных (линейная/логистическая регрессия, random forest, xgboost и т.д.) Парсинг данных из открытых источников как дополнительное преимущество Умение работать в команде  Условия:  Дружная разносторонняя команда Уникальные масштабные проекты и сложные разноплановые задачи. Участие в различных конференциях, митапах банка и корпоративных мероприятиях. Обучение за счёт банка (онлайн и офлайн, в т. ч. на внешних платформах). Оформление по ТК на 6 месяцев на ставку стажера. В случае успешного прохождения стажировки, перевод на постоянную должность. ДМС, спортзал, сниженные ставки по кредитам, дисконт-программы от множества компаний-партнеров. Возможность принять участие в других крупных и уникальных проектах банка.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 1213                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. Мы ищем старшего менеджера по сопровождению клиентов. Его главная задача – помогать клиентам с оформлением продуктов и услуг Сбера и экосистемы, а также консультировать по возникающим вопросам. Эта вакансия для тех, кто хочет развивать навыки эффективных продаж и стоить карьеру в банковской сфере. Эта работа подойдет тебе если ты: · специалист со средним профессиональным, неполным высшим или высшим образованием · имеешь опыт работы в сфере продаж, обслуживания и консультирования клиентов от 6 месяцев · доброжелателен и готов помогать клиентам. Тебе предстоит: · предлагать продукты и услуги Сбера · консультировать клиентов по возникающим вопросам · помогать клиентам оформлять услуги и необходимые для них документы · совершать транзакционные операции в рамках оформления продаж и постпродажного сопровождения клиентов · вести базы клиентов. Работа в Сбере – это: · стабильный оклад и социальная поддержка сотрудников · официальное оформление с первого дня · расширенный ДМС с первого дня и льготное страхование для близких · корпоративное обучение в Виртуальной школе Сбера · бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров · корпоративная пенсионная программа · ипотека выгоднее на 4% для каждого сотрудника. Присоединяйся к команде старших клиентских менеджеров Сбера!
# 1214                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. У каждого нашего зарплатного клиента – компаний партнеров — есть свой эксперт по финансовым вопросам. Он приезжает в офисы партнеров банка несколько раз в неделю, презентует наши продукты, консультирует сотрудников компании по продуктам и сервисам, а также помогает с их оформлением.<br />Это работа для тех, кому интересны сфера продаж, развитие навыков убеждения, личных переговоров и выступлений. А также привлекает работа вне офиса. Тебе предстоит:  выезжать к клиентам на индивидуальные консультации проводить презентации сервисов Сбера на территории компаний-партнеров предлагать сервисы Сбера и помогать с их оформлением.  Работа в Сбере – это:   стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня расширенный ДМС с первого дня и льготное страхование для близких мобильная связь, корпоративный ipad оплата транспортных расходов теплая база клиентов корпоративное обучение в Виртуальной школе Сбера бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративная пенсионная программа ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде клиентских менеджеров Сбера!
# 1215                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. Сбер ищет клиентского менеджера для работы в мобильных офисах. Это специалист, который консультирует клиентов по продуктам, услугам и сервисам Сбера в торговых центрах, аэропортах и гипермаркетах. Эта работа для активных и общительных людей, которые стремятся к карьере и финансовому достатку. Ты подходишь нам, если ты готов:  продавать банковские продукты и сервисы в мобильных офисах Сбера: торговых центрах, магазинах, гипермаркетах, аэропортах рассказывать клиентам о преимуществах сервисов Сбера и экосистемы помогать клиентам оформлять продукты и услуги Сбера.  Опыт работы консультантом или промоутером приветствуется. Работа в Сбере – это:  стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня гибкий график работы, можно совмещать с учебой мобильная связь и корпоративный ipad оплата транспортных расходов корпоративная пенсионная программа расширенный ДМС с первого дня и льготное страхование для близких бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративное обучение в Виртуальной школе Сбера ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде клиентских менеджеров Сбера!
# 1216                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. У каждого нашего зарплатного клиента – компаний партнеров — есть свой эксперт по финансовым вопросам. Он приезжает в офисы партнеров банка несколько раз в неделю, презентует наши продукты, консультирует сотрудников компании по продуктам и сервисам, а также помогает с их оформлением.<br />Это работа для тех, кому интересны сфера продаж, развитие навыков убеждения, личных переговоров и выступлений. А также привлекает работа вне офиса. Тебе предстоит:  выезжать к клиентам на индивидуальные консультации проводить презентации сервисов Сбера на территории компаний-партнеров предлагать сервисы Сбера и помогать с их оформлением.  Работа в Сбере – это:   стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня расширенный ДМС с первого дня и льготное страхование для близких мобильная связь, корпоративный ipad оплата транспортных расходов теплая база клиентов корпоративное обучение в Виртуальной школе Сбера бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративная пенсионная программа ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде клиентских менеджеров Сбера!
# 1217                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Сбер — лучший работодатель России. У нас более 60 компаний экосистемы и 14 тысяч подразделений по всей стране. У каждого нашего зарплатного клиента – компаний партнеров — есть свой эксперт по финансовым вопросам. Он приезжает в офисы партнеров банка несколько раз в неделю, презентует наши продукты, консультирует сотрудников компании по продуктам и сервисам, а также помогает с их оформлением.<br />Это работа для тех, кому интересны сфера продаж, развитие навыков убеждения, личных переговоров и выступлений. А также привлекает работа вне офиса. Тебе предстоит:  выезжать к клиентам на индивидуальные консультации проводить презентации сервисов Сбера на территории компаний-партнеров предлагать сервисы Сбера и помогать с их оформлением.  Работа в Сбере – это:   стабильный оклад и социальная поддержка сотрудников официальное оформление с первого дня расширенный ДМС с первого дня и льготное страхование для близких мобильная связь, корпоративный ipad оплата транспортных расходов теплая база клиентов корпоративное обучение в Виртуальной школе Сбера бесплатная подписка СберПрайм+, скидки на продукты компаний-партнеров корпоративная пенсионная программа ипотека выгоднее на 4% для каждого сотрудника.  Присоединяйся к команде клиентских менеджеров Сбера!
#
# [1218 rows x 3 columns]

# %% [markdown]
# ###### - Создание DataFrame и добавление поля skills:

# %%
df_hh['skills'] = df_hh['key_skills'].apply(lambda s: [x.get('name') for x in s]).tolist()

# %%
df_hh[['id', 'name', 'skills']]
# Out:
#             id  \
# 0     55415805
# 1     68363939
# 2     68899553
# 3     67349462
# 4     68704654
# ...        ...
# 1213  68787346
# 1214  67799534
# 1215  67799754
# 1216  67799537
# 1217  67799535
#
#                                                                      name  \
# 0                                          Менеджер по работе с клиентами
# 1                                                  Финансовый консультант
# 2     Разработчик интерфейсов/frontend разработчик (стажер) в SberDevices
# 3                                             Старший клиентский менеджер
# 4                                                   Стажер Data scientist
# ...                                                                   ...
# 1213                                          Старший клиентский менеджер
# 1214                                    Клиентский менеджер прямых продаж
# 1215                                       Менеджер по работе с клиентами
# 1216                                    Клиентский менеджер прямых продаж
# 1217                                    Клиентский менеджер прямых продаж
#
#                                                                                                                                 skills
# 0                                                                                                                                   []
# 1                                                                          [Работа в команде, Активные продажи, Телефонные переговоры]
# 2                                                                                            [JavaScript, CSS, HTML, TypeScript, CSS3]
# 3                                                                                                                                   []
# 4                                                                                                                        [Python, SQL]
# ...                                                                                                                                ...
# 1213  [Деловая переписка, Деловое общение, Развитие продаж, Деловая коммуникация, Заключение договоров, B2C продажи, Активные продажи]
# 1214                                          [Проведение презентаций, Поиск и привлечение клиентов, Холодные продажи, Прямые продажи]
# 1215                                                                                              [Активные продажи, Холодные продажи]
# 1216                                          [Проведение презентаций, Поиск и привлечение клиентов, Холодные продажи, Прямые продажи]
# 1217                                          [Проведение презентаций, Поиск и привлечение клиентов, Холодные продажи, Прямые продажи]
#
# [1218 rows x 3 columns]

# %% [markdown]
# ###### - Переведите даты публикаций в datetime:

# %%
df_hh['published_at']
# Out:
# 0       2022-08-17T13:51:57+0300
# 1       2022-08-01T18:57:37+0300
# 2       2022-08-17T20:37:17+0300
# 3       2022-08-15T11:51:52+0300
# 4       2022-08-11T22:06:49+0300
#                   ...
# 1213    2022-08-17T09:09:31+0300
# 1214    2022-08-17T09:13:22+0300
# 1215    2022-08-17T09:13:22+0300
# 1216    2022-08-17T09:13:23+0300
# 1217    2022-08-17T09:13:22+0300
# Name: published_at, Length: 1218, dtype: object

# %%
df_hh['published_datetime'] = pd.to_datetime(df_hh['published_at'])

# %%
df_hh[['id', 'name', 'published_datetime']]
# Out:
#             id  \
# 0     55415805
# 1     68363939
# 2     68899553
# 3     67349462
# 4     68704654
# ...        ...
# 1213  68787346
# 1214  67799534
# 1215  67799754
# 1216  67799537
# 1217  67799535
#
#                                                                      name  \
# 0                                          Менеджер по работе с клиентами
# 1                                                  Финансовый консультант
# 2     Разработчик интерфейсов/frontend разработчик (стажер) в SberDevices
# 3                                             Старший клиентский менеджер
# 4                                                   Стажер Data scientist
# ...                                                                   ...
# 1213                                          Старший клиентский менеджер
# 1214                                    Клиентский менеджер прямых продаж
# 1215                                       Менеджер по работе с клиентами
# 1216                                    Клиентский менеджер прямых продаж
# 1217                                    Клиентский менеджер прямых продаж
#
#             published_datetime
# 0    2022-08-17 13:51:57+03:00
# 1    2022-08-01 18:57:37+03:00
# 2    2022-08-17 20:37:17+03:00
# 3    2022-08-15 11:51:52+03:00
# 4    2022-08-11 22:06:49+03:00
# ...                        ...
# 1213 2022-08-17 09:09:31+03:00
# 1214 2022-08-17 09:13:22+03:00
# 1215 2022-08-17 09:13:22+03:00
# 1216 2022-08-17 09:13:23+03:00
# 1217 2022-08-17 09:13:22+03:00
#
# [1218 rows x 3 columns]

# %%
df_hh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 88 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            1218 non-null   object
#  1   premium                       1218 non-null   bool
#  2   relations                     1218 non-null   object
#  3   name                          1218 non-null   object
#  4   insider_interview             0 non-null      object
#  5   response_letter_required      1218 non-null   bool
#  6   address                       0 non-null      float64
#  7   allow_messages                1218 non-null   bool
#  8   contacts                      0 non-null      object
#  9   description                   1218 non-null   object
#  10  branded_description           975 non-null    object
#  11  vacancy_constructor_template  0 non-null      object
#  12  key_skills                    1218 non-null   object
#  13  accept_handicapped            1218 non-null   bool
#  14  accept_kids                   1218 non-null   bool
#  15  archived                      1218 non-null   bool
#  16  response_url                  18 non-null     object
#  17  specializations               1218 non-null   object
#  18  professional_roles            1218 non-null   object
#  19  code                          18 non-null     object
#  20  hidden                        1218 non-null   bool
#  21  quick_responses_allowed       1218 non-null   bool
#  22  driver_license_types          1218 non-null   object
#  23  accept_incomplete_resumes     1218 non-null   bool
#  24  published_at                  1218 non-null   object
#  25  created_at                    1218 non-null   object
#  26  initial_created_at            1218 non-null   object
#  27  negotiations_url              0 non-null      object
#  28  suitable_resumes_url          0 non-null      object
#  29  apply_alternate_url           1218 non-null   object
#  30  has_test                      1218 non-null   bool
#  31  test                          0 non-null      float64
#  32  alternate_url                 1218 non-null   object
#  33  working_days                  1218 non-null   object
#  34  working_time_intervals        1218 non-null   object
#  35  working_time_modes            1218 non-null   object
#  36  accept_temporary              1218 non-null   bool
#  37  languages                     1218 non-null   object
#  38  billing_type.id               1218 non-null   object
#  39  billing_type.name             1218 non-null   object
#  40  area.id                       1218 non-null   object
#  41  area.name                     1218 non-null   object
#  42  area.url                      1218 non-null   object
#  43  salary.from                   99 non-null     float64
#  44  salary.to                     40 non-null     float64
#  45  salary.currency               107 non-null    object
#  46  salary.gross                  107 non-null    object
#  47  type.id                       1218 non-null   object
#  48  type.name                     1218 non-null   object
#  49  experience.id                 1218 non-null   object
#  50  experience.name               1218 non-null   object
#  51  schedule.id                   1218 non-null   object
#  52  schedule.name                 1218 non-null   object
#  53  employment.id                 1218 non-null   object
#  54  employment.name               1218 non-null   object
#  55  department.id                 1169 non-null   object
#  56  department.name               1169 non-null   object
#  57  employer.id                   1218 non-null   object
#  58  employer.name                 1218 non-null   object
#  59  employer.url                  1218 non-null   object
#  60  employer.alternate_url        1218 non-null   object
#  61  employer.logo_urls.original   1218 non-null   object
#  62  employer.logo_urls.90         1218 non-null   object
#  63  employer.logo_urls.240        1218 non-null   object
#  64  employer.vacancies_url        1218 non-null   object
#  65  employer.trusted              1218 non-null   bool
#  66  address.city                  418 non-null    object
#  67  address.street                408 non-null    object
#  68  address.building              404 non-null    object
#  69  address.description           0 non-null      float64
#  70  address.lat                   418 non-null    float64
#  71  address.lng                   418 non-null    float64
#  72  address.raw                   418 non-null    object
#  73  address.metro.station_name    378 non-null    object
#  74  address.metro.line_name       378 non-null    object
#  75  address.metro.station_id      378 non-null    object
#  76  address.metro.line_id         378 non-null    object
#  77  address.metro.lat             378 non-null    float64
#  78  address.metro.lng             378 non-null    float64
#  79  address.metro_stations        441 non-null    object
#  80  salary                        0 non-null      float64
#  81  department                    0 non-null      float64
#  82  test.required                 2 non-null      object
#  83  address.metro                 0 non-null      float64
#  84  immediate_redirect_url        18 non-null     object
#  85  description_len               1218 non-null   int64
#  86  skills                        1218 non-null   object
#  87  published_datetime            1218 non-null   datetime64[ns, pytz.FixedOffset(180)]
# dtypes: bool(12), datetime64[ns, pytz.FixedOffset(180)](1), float64(12), int64(1), object(62)
# memory usage: 737.6+ KB

# %% [markdown]
# ###### - Постройте график опубликованных вакансий по датам:

# %%
df_hh_date = df_hh[['id', 'published_datetime']]
df_hh_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  1218 non-null   object
#  1   published_datetime  1218 non-null   datetime64[ns, pytz.FixedOffset(180)]
# dtypes: datetime64[ns, pytz.FixedOffset(180)](1), object(1)
# memory usage: 19.2+ KB

# %%
df_hh_date
# Out:
#             id        published_datetime
# 0     55415805 2022-08-17 13:51:57+03:00
# 1     68363939 2022-08-01 18:57:37+03:00
# 2     68899553 2022-08-17 20:37:17+03:00
# 3     67349462 2022-08-15 11:51:52+03:00
# 4     68704654 2022-08-11 22:06:49+03:00
# ...        ...                       ...
# 1213  68787346 2022-08-17 09:09:31+03:00
# 1214  67799534 2022-08-17 09:13:22+03:00
# 1215  67799754 2022-08-17 09:13:22+03:00
# 1216  67799537 2022-08-17 09:13:23+03:00
# 1217  67799535 2022-08-17 09:13:22+03:00
#
# [1218 rows x 2 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt
df_hh_date.groupby([df_hh_date.published_datetime.dt.date])['id'].count().plot(kind = 'line', xlabel = 'Дата', ylabel = 'Кол-во вакансий')
plt.xticks(rotation=45, horizontalalignment='right', fontweight='light', fontsize='medium')
plt.show()

# %% [markdown]
# ###### - Переведите даты в дни недели, и определите день недели, в который больше всего публикуют вакансий:

# %%
df_hh_date['day_name'] = df_hh_date.published_datetime.dt.day_name()
# Out:
# C:\Users\vitg1\AppData\Local\Temp\ipykernel_16808\2361581018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hh_date['day_name'] = df_hh_date.published_datetime.dt.day_name()

# %%
df_hh_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  1218 non-null   object
#  1   published_datetime  1218 non-null   datetime64[ns, pytz.FixedOffset(180)]
#  2   day_name            1218 non-null   object
# dtypes: datetime64[ns, pytz.FixedOffset(180)](1), object(2)
# memory usage: 28.7+ KB

# %%
df_hh_date
# Out:
#             id        published_datetime   day_name
# 0     55415805 2022-08-17 13:51:57+03:00  Wednesday
# 1     68363939 2022-08-01 18:57:37+03:00     Monday
# 2     68899553 2022-08-17 20:37:17+03:00  Wednesday
# 3     67349462 2022-08-15 11:51:52+03:00     Monday
# 4     68704654 2022-08-11 22:06:49+03:00   Thursday
# ...        ...                       ...        ...
# 1213  68787346 2022-08-17 09:09:31+03:00  Wednesday
# 1214  67799534 2022-08-17 09:13:22+03:00  Wednesday
# 1215  67799754 2022-08-17 09:13:22+03:00  Wednesday
# 1216  67799537 2022-08-17 09:13:23+03:00  Wednesday
# 1217  67799535 2022-08-17 09:13:22+03:00  Wednesday
#
# [1218 rows x 3 columns]

# %%
df_hh_date.day_name.mode()
# Out:
# 0    Monday
# Name: day_name, dtype: object

# %%
df_hh_date.groupby('day_name')['id'].count()
# Out:
# day_name
# Friday       174
# Monday       324
# Saturday      13
# Sunday        14
# Thursday     181
# Tuesday      265
# Wednesday    247
# Name: id, dtype: int64

# %% [markdown]
# ###### - Найдите те вакансии с использованием python, которые вам интересны:

# %%
id = df_hh.skills.apply(lambda x: 'Python' in x)
df_hh_interesting = df_hh[id]
df_hh_interesting = df_hh_interesting[df_hh_interesting['name'].str.contains('аналитик') | df_hh_interesting['name'].str.contains('Аналитик')]

# %%
df_hh_interesting[['id', 'name', 'description', 'skills']]
# Out:
#             id  \
# 24    66523856
# 101   68619804
# 105   68509921
# 112   67752294
# 152   67414601
# 176   68379084
# 305   66099561
# 342   68662845
# 531   68363814
# 552   68641184
# 606   68659358
# 790   68643635
# 911   68123813
# 1081  68235765
#
#                                                                                                    name  \
# 24                                                                                         Аналитик SQL
# 101                                                                                            Аналитик
# 105                                                                                     Аналитик данных
# 112                                                                               Аналитик данных (SQL)
# 152                                                                                            Аналитик
# 176                                                                                Продуктовый аналитик
# 305                                                                 Data аналитик (Рекламная платформа)
# 342                                                                      Аналитик в команду кампейнинга
# 531                                                                                Аналитик SberDevices
# 552   Аналитик данных (лист-менеджер) в команду разработки персональных коммуникаций Розничного бизнеса
# 606                                                           Аналитик по цифровому описанию архитектур
# 790                                                                           Системный аналитик (ППРБ)
# 911                                                                                       Дата аналитик
# 1081                                                                      Системный аналитик (Big data)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         description  \
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Блок &quot;Сеть продаж&quot; курирует все физические каналы касания клиента с экосистемой (отделения, банкоматы, агентская сеть и тд). Мы разрабатываем и внедряем end-to-end решения на основе машинного обучения в бизнес-процессы, связанные с обслуживанием клиентов. На данный момент мы в поисках крутого Аналитика SQL :)   Задачи:   Проверка гипотез на больших массивах данных (в т.ч. при необходимости с использованием методов машинного обучения) Выявление ключевых факторов и причинно-следственных связей Статистический анализ данных Работа с Teradata, GreenPlum Анализ воронок продаж и склонностей клиентов к покупкам и т.д.    Наши ожидания: - Высшее образование (математика/физика/программирование/экономика) - Знания SQL - Навыки работы с Python (приветствуется)   Мы предлагаем:  Возможность участвовать в амбициозных проектах крупнейшего Банка страны. Разнообразные и интересные задачи в области анализа и исследования бизнес-показателей. Возможности для профессионального и личностного роста в динамично развивающемся коллективе большой компании. Профессиональное развитие в области работы с данными. Конкурентная заработная плата. Cоциальный пакет (ДМС, НПФ, спортзал).
# 101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Наша команда разрабатывает AI сервисы, помогающие разработчику при написании им кода. Наши сервисы построены на новейших достижениях Data Science в области обработки языков программирования и естественного языка. Наша цель – снизить когнитивную нагрузку на разработчика, облегчить порог вхождения в новые области и сделать процесс написания кода более продуктивным в целом. Если ты опытный аналитик, любишь решать сложные задачи и хочешь делать продукт для разработчиков - эта позиция для тебя. обязанности  Работать с требованиями к продукту, детализировать фичи, придумывать варианты их продуктовой реализации Общаться с контрагентами и консолидировать информацию для команды Заниматься описанием продукта Участвовать в продуктовых исследованиях и развитии продукта Работа в команде: agile церемонии, нацеленность на командный результат, возможность предлагать идею и реализовывать ее совместно  требования  Опять работы в роле бизнес или системного аналитика от 2-х лет Отличных коммуникативных навыков Опыта разработки или желания серьезно погрузиться в эту область Грамотной письменной и устной речи Умения писать технические требования и документацию    Будет плюсом:    Знания об архитектуре и работе языков программирования Опыт программирования на Python, JavaScript, NodeJS, Kotlin, C/C++ Опыт/знания в области DataScience Опыт проведения продуктовых исследований
# 105                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Сбер — больше чем банк, это динамично развивающаяся экосистема для улучшения повседневной жизни человека. Наша цель - внедряя передовые IT-продукты и сервисы, конкурировать с глобальными технологическими компаниями, оставаясь лучшим банком для населения и бизнеса. Чем выше цель – тем больше задач и информации необходимо отработать, в связи с этим мы ищем аналитиков данных в различные дивизионы. Если тебе интересно направление анализа данных, ты хочешь работать в банке с самым сильным и дорогим брендом в мире по версии Brand Finance, откликайся на нашу вакансию. Обязанности:  поиск и анализ данных из разрозненных источников, разработка и анализ математических моделей визуализация и интерпретация полученных результатов анализа проверка гипотез на данных и обработка ad-hoc запросов оценка выявленных отклонений, предложения по их устранению и совершенствование системы отчетности проведение аналитических исследований в рамках курируемого направления/проекта  Требования:  высшее образование техническое или экономическое опыт анализа больших объемов данных, построения моделей, прогнозирования на будущие периоды или отсутствие опыта, но знание математической статистики и методов статистического анализа данных (кластеризация, регрессионный, факторный, дисперсионный и корреляционный анализы) опыт автоматизации или оптимизации процессов опыт работы с СУБД: Teradata или Oracle или Greenplum как преимущество; с языками программирования: SQL и Python опыт работы с Power BI или Сonfluence или QLIK Sense или Visio будет преимуществом  Условия:  работа в динамично развивающейся экосистеме стабильный оклад и систему непрерывных бонусов ДМС и программы лояльности для сотрудников в рамках всей экосистемы безграничные возможности горизонтального и вертикального роста возможность постоянного обучения на базе внутреннего университета экосистемы или внешних партнеров работа в командах прогрессивно мыслящих и энергичных людей рабочее место в современном офисе с возможностью отдыха в течение дня: lounge-зоны, зоны коворкинга, кафе, оборудованные кухни, спортивный зал и спортивные групповые программы
# 112                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Блок &quot;Сеть продаж&quot; курирует все физические каналы касания клиента с экосистемой (отделения, банкоматы, агентская сеть и тд). Мы разрабатываем и внедряем end-to-end решения на основе машинного обучения в бизнес-процессы, связанные с обслуживанием клиентов. Сейчас мы ищем Аналитика SQL в команду, которая развивает интеллектуальную систему управления для руководителей подразделений блока Сети продаж.   Чем придется заниматься:   Проверка гипотез на больших массивах данных (в т.ч. при необходимости с использованием методов машинного обучения) Выявление ключевых факторов и причинно-следственных связей Статистический анализ данных Работа с Teradata, GreenPlum    Наши ожидания:  Умение проверять гипотезы с использованием математических инструментов; Опыт написания запросов, хранимых процедур и оптимизации запросов на SQL; Высокий уровень использования Excel c макросами; Опыт анализа данных с использованием Python: Jupyter, библиотеки; Опыт работы с реляционными СУБД (PostgreSQL, GreenPlum); Опыт создания аналитического хранилища (DWH);    Мы предлагаем:  Возможность участвовать в амбициозных проектах крупнейшего Банка страны. Разнообразные и интересные задачи в области анализа и исследования бизнес-показателей. Возможности для профессионального и личностного роста в динамично развивающемся коллективе большой компании. Профессиональное развитие в области работы с данными. Конкурентная заработная плата. Cоциальный пакет (ДМС, НПФ, спортзал).
# 152                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Обязанности:  Подготовка управленческой отчетности по направлению эффективности розничного взыскания; Анализ и мониторинг портфеля розничных клиентов; Аd-hoc аналитика по взысканию, резервам, качеству розничного портфеля и портфеля реструктуризации; Подготовка материалов (презентаций) для top-менеджмента; Автоматизация банковской отчётности.  Требования:  Образование высшее (Финансы/банки,Математика); Знание СУБД на уровне выше среднего в части написания сложных запросов, процедур (SQL, Teradata, Oracle, Postrge - greenplum); Опыт подготовки управленческой отчетности и ad-hoc аналитики; Опыт работы в рисках, финансах, collection; Понимание банковских портфельных риск-метрик (recovery rate, inflow rate, hazard rate, roll rate; Знание основ математической статистики, а также бухгалтерского учета в части резервирования, IFRS9; Знание Python как преимущество.  Условия:  Стабильную работу в высокопрофессиональной среде; Карьерный путь в международной организации; Возможность заметно влиять на бизнес банка; ДМС, фитнес-центр; Корпоративное обучение, курсы и тренинги; Современный офис в Москве на Кутузовском.
# 176                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           SberDevices — уникальное IT-пространство внутри Сбера. Мы занимаемся разработкой голосовых продуктов, умных устройств и виртуальных ассистентов. <br />Задачи:  Построение продуктовой аналитики команды, анализ данных Построение аналитических отчётов и дашбордов в Metabase на основе данных из DWH (GreenPlum (PostgreSQL) + Clickhouse) Сегментация пользователей и исследование данных для поиска возможностей роста Выдвижение продуктовых гипотез и их валидация через эксперименты  Требования:  Уверенное владение SQL, Python Опыт работы с BI-системами - PowerBI, Tableau, Qlik. Большим плюсом будет опыт работы с Metabase Опыт работы с платформами продуктовой аналитики - Amplitude, Mixpanel, GA, Я.Метрика или аналогичные Знакомство со статистикой (проверка гипотез, A/B тесты) и методами сегментации пользователей Опыт работы с ELK, Airflow - будет плюсом  <br />Условия:  Конкурентную компенсацию (оклад и премии по результатам деятельности) Свободный дресс-код Гибкий график для оптимального баланса работы и личной жизни Профессиональное обучение, семинары, тренинги, конференции, корпоративная библиотека ДМС, страхование жизни Самые инновационные, амбициозные проекты и задачи Льготные кредиты и корпоративные скидки
# 305                                                                                                                                                                                                                                                                                               Кто мы? Продуктовая команда &quot;Индустрии Рекламы&quot; Сбера, которая ищет тебя - специалиста в области разработки! Наш продукт - модуль &quot;Автоматическая модерация и разметка рекламных кампаний; рекламодателей; рекламных площадок&quot;. Этот Модуль - часть создаваемой платформы по управлению рекламой на всех digital-поверхностях Сбера и его партнеров. Наша цель - определение правильных и пригодных кампаний от всех рекламодателей, которые хотят разместить рекламные объявления на digital-поверхностях экосистемы Сбера и его партнеров. Если ты талантливый и амбициозный специалист в сфере ИТ, если ты хочешь быть причастными к созданию лучших продуктов для лучших клиентов и уверенно отвечать за результаты, то мы рады принять тебя в команду. Обязанности: Команда качества ранжирования занимается всем циклом отбора рекламы в SberAds. Мы занимаемся как непосредственно машинным обучением, так и его технической инфраструктурой. Работая бок о бок с командой сервисов ранжирования создаются сервисы, которые в реальном времени подбирают для пользователей наиболее релевантную рекламу. Качество прогнозов наших моделей напрямую влияет на выручку SberAds и поэтому основная наша цель это рост качества алгоритмов.   В рамках данной позиции предстоит:  Проведение ad-hoc аналитики на данных рекламы (Hive, Spark, SQL); Визуализация отчетности в BI инструментах (SuperSet, Qlik); Работа с алгоритмами ML, подготовка обучающих выборок, анализ и сбор метрик.  Требования:  Хорошие знания SQL, опыт работы с одной из реляционной БД - Oracle/PostgreSQL/mySQL/MS SQL Server; Уверенная работа с Python; Опыт аналитики с использованием инструментов Spark Streaming, Hbase, Spark, Kafka, Hive, Impala, Hue и т.д.; Навыки построения аналитических отчетов и дашбордов в BI инструментах. Понимание принципов модели распределенных вычислений, принципов организации Data Lake/DWH; Понимание подходов к организации разработки CI/CD.  Условия:  Официальное трудоустройство согласно ТК РФ; Белая заработная плата (оклад + годовая премия); Страхование (от несчастных случаев, ДМС); Оздоровительные программы для детей сотрудников; Возможность обучения за счет компании; Выплаты материальной помощи в особых/чрезвычайных случаях; Дисконт-программы от компаний партнеров (фитнес, страхование, туризм); Льготное кредитование; Корпоративные цены на абонементы в крупные фитнес-сети; Комфортный офис и график работы 5/2
# 342                                                                                                                                                                                                                                                                                                                                                                                                                                                           Команда кампейнинга Розничного бизнеса формирует персональные предложения по страховым и пенсионным продуктам для физических лиц (ипотечное-, автострахование, спортивные страховки, защита жизни и здоровья, имущества, индивидуальный пенсионный план и т.д.). Для доставки предложений используются физические и цифровые каналы (отделения продаж, мобильное и Web приложения, sms, push, email, телемаркетиинг и другие). Цель – выбрать лучшее предложение для закрытия клиентской потребности и отвечающее задачам Группы. Обязанности  формирование кампаний продаж на клиентов Банка для продвижения продуктов и сервисов Банка (выстраивание алгоритмов приоритизации предложений) посредством SQL-запросов, работой в CRM, SAS разработка аналитической отчетности анализ данных по процессам взаимодействия с клиентами Банка, эффективности кампаний продаж, достижению бизнес-показателей (средствами Teradata (SQL), Python, в перспективе - Hive, Impala, Spark) понимание процессов коммуникации с клиентами (построение и проверка бизнес-гипотез) при необходимости визуализация данных (PowerPoint), в том числе с использованием специализированных BI-инструментов (Qlik View)  Требования  высшее образование по направлению: прикладная математика/физика/ИТ/финансы желателен опыт работы в банковской сфере, понимание внутрибанковских процессов и знание банковских продуктов и услуг отличное знание Excel (VBA будет являться преимуществом) владение методами анализа данных и инструментами подготовки отчетности опыт работы с базами данных, навыки написания сложных SQL-запросов обязательны (Teradata, Oracle, SAS, MS SQL) опыт работы с инструментами визуализации данных является преимуществом (в идеале - Qlik View) знание Python является преимуществом  Условия  полный рабочий день, но гибкий график работы (можно выбрать режим начала работы в промежутке 7:00 - 10:30) достойная заработная плата (оклад + внушительные премии) оформление по ТК РФ социальный пакет (ДМС) комфортный офис Agile Home возможность посещения конференций, обучения и сертификации за счет компании (в т.ч. английский язык) программа льготного кредитования в Сбербанке дисконт-программы от множества компаний партнеров возможность принять участие в других крупных и уникальных проектах банка
# 531                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Задача позиции – помочь маркетингу собирать и анализировать данные и принимать наиболее правильные решения по дальнейшему планированию продвижения и эффективному распределению бюджета. Обязанности:  Создание единого аналитического продукта, который позволит систематизировать и визуализировать данные из разрозненных рекламных систем (включая нестандартные); Взаимодействие с партнерами/площадками о предоставлении необходимых данных; Аналитика получаемых результатов, совместно с медиаменеджерами поиск инсайты для оптимизации размещений; Выявление потребности медиаменеджеров в новых наборах/разрезах данных для дальнейшего планирования.  Требования:  Опыт работы аналитиком BI / данных от 2 лет; Уверенные знания SQL, Python; Опыт внедрения различных систем сбора, хранения и визуализации статистики; Владение методиками анализа данных, используя различные инструменты; Опыт взаимодействия с бизнес- заказчиками; Высшее образование.  Условия:  Стабильный оклад и социальную поддержку сотрудников; Официальное оформление; Расширенный ДМС с первого дня и льготное страхование для близких; Корпоративное обучение, возможность посещать внешние конференции в качестве слушателя и спикера; Бесплатную подписку СберПрайм+ и скидки на продукты компаний-партнеров; Корпоративную пенсионную программу; Ипотеку выгоднее на 4% для каждого сотрудника.
# 552                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Цель команды: формирование персональных коммуникаций, исходя из профиля и выявленных на истории предпочтений Клиента по предложению всех пассивных продуктов B2C Банка (вклады, страховки, накопительные счета, инвест. счета и т.д.). Команда работает на бизнес цели. Обязанности  формирование кампаний продаж на клиентов Банка для продвижения продуктов и сервисов Банка (выстраивание алгоритмов приоритизации предложений) посредством SQL-запросов, работой в CRM, SAS анализ данных по процессам взаимодействия с клиентами Банка, эффективности кампаний продаж, достижению бизнес-показателей (средствами Teradata (SQL), Python, в перспективе - Hive, Impala, Spark) понимание процессов коммуникации с клиентами (построение и проверка бизнес-гипотез) при необходимости визуализация данных (PowerPoint), в том числе с использованием специализированных BI-инструментов (Qlik View)  Требования  высшее образование по направлению: прикладная математика/физика/ИТ/финансы желателен опыт работы в банковской сфере, понимание внутрибанковских процессов и знание банковских продуктов и услуг отличное знание Excel (VBA будет являться преимуществом) владение методами анализа данных и инструментами подготовки отчетности опыт работы с базами данных, навыки написания сложных SQL-запросов обязательны (Teradata, Oracle, SAS, MS SQL) знание Python является преимуществом  Условия  полный рабочий день, но гибкий график работы (можно выбрать режим начала работы в промежутке 7:00 - 10:30) достойная заработная плата (оклад + внушительные премии) оформление по ТК РФ социальный пакет (ДМС) комфортный офис Agile Home возможность посещения конференций, обучения и сертификации за счет компании (в т.ч. английский язык) программа льготного кредитования в Сбербанке дисконт-программы от множества компаний партнеров возможность принять участие в других крупных и уникальных проектах банка
# 606                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Мы - Департамент Корпоративной Архитектуры. Мы расширяем нашу команду, которая отвечает за описание архитектур автоматизированных систем. Обязанности:  Коммуникация с представителями команд разработки и сопровождения автоматизированной системы (АС) по сбору, анализу, формализации архитектуры системы; Коммуникация с представителями смежных команд по вопросам интеграции; Консультирование архитекторов по модели архитектуры АС и использованию ее в производственном процессе банка; Формирование описания архитектуры АС в виде набора объектов; Выявление проблемных мест (недостатки модели архитектуры, методологии описания, неудобный UI/UX и т.п.). Поддержка внутренней базы знаний по описанию архитектуры АС.  Требования:   Опыт работы системным аналитиком/ архитектором от 2-х лет;   Владение принципами построения клиент-серверной архитектуры приложений, представление о слоях архитектуры, понимание принципов применения современных архитектурных фреймворков (TOGAF, C4 и т.п.);   Знание подходов к построению микросервисной архитектуры;   Знание жизненного цикла ПО, построения DevOps-конвейера;   Понимание практик контейнеризации приложений и оркестраторах (Docker, Kubernetes/Openshift);   Владение различными подходами и особенностями построения БД (понимание принципов проектирования схема данных);   Понимание особенностей различных технологий интеграции: HTTP, очереди, файлы:   Понимание управления API, принципов построения современных API. Знание устройства и применения REST API;   Опыт работы с Jira и Confluence.   Условия:  Работа в команде профессионалов, возможность участия в разработке уникальных и интересных решений; Достойная заработная плата (оклад + премии); Большой и комфортный офис со спортзалом и кафе для сотрудников; Обучение в корпоративном университете; ДМС для сотрудников и скидки на медицинскую страховку для родственников; Широкий спектр дисконт-программ, скидок и привилегий от компаний-партнеров.
# 790   Мы команда SberData ищем сильного аналитика с опытом и желанием развиваться в направлении BigData и построении распределенных систем. Мы - команда ядра, отвечающая за разработку сервиса потоковой поставки данных в Hadoop из крупнейшей backend-платформы Банка. Мы обрабатываем и поставляем в Hadoop реально большие объемы данных, причем делаем это в режиме near real-time. Наша задача быстро и качественно обеспечить поставку данных потребителям, проконтролировать качество и цлеостность поставленных данных и обеспечить их безопасность. Это настоящая BigData в одной из крупнейших IT-компаний России.<br />Используем следующие продукты: Kafka, HBase, SpringBootYarn, Spark, Hive, MapReduce и кодим на java. Обязанности:  Сбор, анализ и подготовка функциональных и нефункциональных требований, в т.ч. требований к надежности, производительности и безопасности Участие в создании детальных архитектур решения (solution-архитектур) Поиск новых идей, их описание и защита на архитектурной группе (product owner + архитектор + team lead) Подготовка и детализация agile-историй, детализация критериев приемки и подготовка методик испытаний нового функционала продукта Подготовка технических заданий на разработку автоматизированных тестов Консультирование разработчиков и инженеров поддержки Участие в разборе инцидентов качества и производительности Активное участие во всех agile-церемониях команды, организация и проведение демо продукта для внешних команд, обучение работе с продуктом  Требования:  Опыт работы от 1.5 лет в области системного анализа/составления функциональных требований/ технических спецификаций (документации) по разработке ПО Понимание жизненного цикла разработки ПО, знание методологий разработки Понимание принципов реляционных и NoSQL баз данных, построения хранилищ данных Понимание принципов проектирования распределенных систем Опыт работы с Linux на уровне опытного пользователя и выше Опыт разработки на одном из языков: Java, C/C++, Python Опыт работы с SQL и написания сложных запросов Опыт работы со стеком Hadoop (HDFS, Yarn, Hive, Spark, Oozie) Опыт работы с Kafka, HBase будет большим плюсом Опыт работы с большим объемом данных в Excel, использование аналитических функций Excel Умение наглядно изложить свои мысли и идеи в виде схемы Умение и желание писать понятную и удобную документацию  Условия:  Профессиональное обучение, семинары, тренинги, конференции, корпоративная библиотека ДМС, страхование жизни Самые инновационные, амбициозные проекты и задачи Свободный дресс-код Гибкий график для оптимального баланса работы и личной жизни Льготные кредиты и корпоративные скидки Конкурентная компенсация (оклад и премии по результатам деятельности)
# 911                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Сбер — больше чем банк, это динамично развивающаяся экосистема для улучшения повседневной жизни человека. Наша цель - внедряя передовые IT-продукты и сервисы, конкурировать с глобальными технологическими компаниями, оставаясь лучшим банком для населения и бизнеса. Чем выше цель – тем больше задач и информации необходимо отработать, в связи с этим мы ищем аналитиков данных в различные дивизионы. Если тебе интересно направление анализа данных, ты хочешь работать в банке с самым сильным и дорогим брендом в мире по версии Brand Finance, откликайся на нашу вакансию. На какие задачи мы тебя приглашаем:  поиск и анализ данных из разрозненных источников, разработка и анализ математических моделей визуализация и интерпретация полученных результатов анализа проверка гипотез на данных и обработка ad-hoc запросов оценка выявленных отклонений, предложения по их устранению и совершенствование системы отчетности проведение аналитических исследований в рамках курируемого направления/проекта  Что мы ждем от тебя:  высшее образование техническое или экономическое опыт анализа больших объемов данных, построения моделей, прогнозирования на будущие периоды или отсутствие опыта, но знание математической статистики и методов статистического анализа данных (кластеризация, регрессионный, факторный, дисперсионный и корреляционный анализы) опыт автоматизации или оптимизации процессов опыт работы с СУБД: Teradata или Oracle или Greenplum как преимущество; с языками программирования: SQL и Python опыт работы с Power BI или Сonfluence или QLIK Sense или Visio будет преимуществом    Что мы предлагаем:  стабильную, конкурентную заработную плату (оклад + бонусы) и социальную поддержку сотрудников регулярные внутренние и внешние митапы корпоративное обучение за счет компании расширенный ДМС с первого дня для сотрудников и льготное страхование для близких комфортный офис с Lounge-зонами, кафе и оборудованными кухнями корпоративный спортзал прямо в офисе бесплатную подписку СберПрайм+, скидки на продукты компаний-партнеров: Okko, Сбер Маркет, Delivery Club, Самокат, Сбер Еаптека и других.
# 1081                                                                                                                                                                                                                                                           В SberData мы создаем централизованное хранилище данных всего Сбера. Это более 350 источников данных и 100+ Пб информации, заказ и получение данных за 15 минут и современный технологический стек работы с данными, включая собственные сборки СУБД на базе Hadoop и Greenplum.   Предметная область: Наша команда создает и развивает продукт для построения Data Lineage на различных технологических стеках хранения и преобразовании информации ( от традиционных РСУБД : Oracle/PostgreSQL/GreenPlum до Hadoop: Hive/Spark). Перед командой стоит задача по созданию продукта не только в рамках платформы Фабрики, но и выхода в экосистему Сбербанка, а далее и на внешний рынок. Data lineage – информация, которая описывает движение данных от источника их происхождения по точкам обработки и применения. В мире Big Data, когда информации становится все больше, Data lineage позволяет управлять данными, реализуя следующие задачи:  Обеспечение качества данных за счет однозначной идентификации их источников; Повышение доверия к данным через прозрачность всех процессов работы с ними; Предоставление метаданных и сведений об их изменении в точках трансформации данных.    Чем предстоит заниматься:  исследование данных различных систем источников Data Linage формирование требований по сбору, хранению и распространению фактического Data Lineage проектирование единой модели Data Lineage проектирование моделей данных для систем источников синхронизация и устранение разрывов единой модели данных, моделей источников, модели приёмников постановка требований и разработка процессов обработки и трансформации Data Lineage (Spark 2,3, Hive) участие в разработке/актуализации архитектуры.    Кто нам нужен:  опыт проектирования и описания процессов знание современных инструментов описания процессов опыт работы с форматами json, xml, xsd, wsdl опыт работы с RDBMS, проектирование структуры, высокий уровне знания SQL знание REST/SOAP опыт использования экосистемы Hadoop (Spark, Hive, Spark ML), Scala или python развитые коммуникативные навыки    Сбер - это:  профессиональный рост в команде экспертов профессиональное обучение, семинары, тренинги, конференции, корпоративная библиотека ДМС, страхование жизни самые инновационные, амбициозные проекты и задачи свободный дресс-код гибкий график для оптимального баланса работы и личной жизни льготные кредиты и корпоративные скидки конкурентная компенсация (оклад и премии по результатам деятельности).
#
#                                                                                                               skills
# 24                                                                                                     [SQL, Python]
# 101                                                  [Python, SQL, Ориентация на результат, C++, Системное мышление]
# 105   [SQL, Python, Статистический анализ, Qlik Sense, Математическая статистика, Анализ данных, Excel, Базы данных]
# 112                                                                                          [SQL, Teradata, Python]
# 152                                   [SQL, Python, Математическая статистика, Математический анализ, MS PowerPoint]
# 176                                           [Python, SQL, PostgreSQL, Tableau, Аналитические исследования, MS SQL]
# 305                                                             [Python, SQL, Data Mining, Oracle BI, Анализ данных]
# 342        [Analysis, SQL, Python, Кампании продаж, Кампейнинг, Excel, Teradata, Spark, Data Analysis, Data Analyst]
# 531                                                     [Python, SQL, Анализ данных, Аналитическое мышление, MS SQL]
# 552                                             [SQL, Data Analysis, Big Data, Teradata, Python, Excel, VBA, ORACLE]
# 606   [Docker, Atlassian Jira, Atlassian Confluence, Kubernetes, Python, Сбор и анализ информации, Системный анализ]
# 790                                                                           [Big Data, SQL, Python, Linux, Hadoop]
# 911                                                                                                    [SQL, Python]
# 1081                                                                      [Python, SQL, Spark, Big Data, PostgreSQL]

# %%
len(df_hh_interesting.index)
# Out:
# 14

# %% [markdown]
# ###### - Определите по полю skills какие навыки больше всего востребованы для этих вакансий:

# %%
list_int_vac_skills = df_hh_interesting['key_skills'].apply(lambda t: ','.join([x.get('name') for x in t])).tolist()
from collections import Counter
top_int_skills = Counter(x for x in ','.join(list_int_vac_skills).split(',') if x != '')
top_int_skills.most_common(1)
# Out:
# [('Python', 14)]

# %% [markdown]
# ###### - Постройте график наиболее востребованных навыков для аналитика данных:

# %%
df_hh_da = df_hh[(df_hh['name'].str.contains('аналитик') | df_hh['name'].str.contains('Аналитик')) & (df_hh['name'].str.contains('данн') | df_hh['name'].str.contains('Data') | df_hh['name'].str.contains('data'))]

# %%
df_hh_da[['id', 'name', 'description', 'skills']]
# Out:
#             id  \
# 105   68509921
# 112   67752294
# 113   68322832
# 129   68650456
# 132   68783029
# 206   67574660
# 230   68773305
# 305   66099561
# 311   68699513
# 338   68042492
# 346   68293172
# 418   68855023
# 487   55420381
# 552   68641184
# 643   68043883
# 783   68781648
# 913   68805233
# 1013  49684144
# 1081  68235765
#
#                                                                                                    name  \
# 105                                                                                     Аналитик данных
# 112                                                                               Аналитик данных (SQL)
# 113                                                                            Менеджер-аналитик данных
# 129                                                                 Риск-аналитик/Аналитик данных (SQL)
# 132                                                                   Аналитик данных , Кампании продаж
# 206                                                                                    Аналитик BigData
# 230                                      Аналитик данных в команду Интеллектуального IVR (Data Analyst)
# 305                                                                 Data аналитик (Рекламная платформа)
# 311                                                                                       Data Аналитик
# 338                                           Аналитик данных (Лист-менеджер) в команду Кредитные карты
# 346                                Senior Business аналитик (SberData, Управление корпоративных данных)
# 418                                                                                       Data-аналитик
# 487                                                                         Аналитик по качеству данных
# 552   Аналитик данных (лист-менеджер) в команду разработки персональных коммуникаций Розничного бизнеса
# 643                                                             Менеджер по сегментации (data аналитик)
# 783                                                                          Data engineer/Аналитик DWH
# 913                                    Системный аналитик (SberData, Управление корпоративными данными)
# 1013                     Системный архитектор/аналитик (Команда архитектуры Хранилища данных, SberData)
# 1081                                                                      Системный аналитик (Big data)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               description  \
# 105                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Сбер — больше чем банк, это динамично развивающаяся экосистема для улучшения повседневной жизни человека. Наша цель - внедряя передовые IT-продукты и сервисы, конкурировать с глобальными технологическими компаниями, оставаясь лучшим банком для населения и бизнеса. Чем выше цель – тем больше задач и информации необходимо отработать, в связи с этим мы ищем аналитиков данных в различные дивизионы. Если тебе интересно направление анализа данных, ты хочешь работать в банке с самым сильным и дорогим брендом в мире по версии Brand Finance, откликайся на нашу вакансию. Обязанности:  поиск и анализ данных из разрозненных источников, разработка и анализ математических моделей визуализация и интерпретация полученных результатов анализа проверка гипотез на данных и обработка ad-hoc запросов оценка выявленных отклонений, предложения по их устранению и совершенствование системы отчетности проведение аналитических исследований в рамках курируемого направления/проекта  Требования:  высшее образование техническое или экономическое опыт анализа больших объемов данных, построения моделей, прогнозирования на будущие периоды или отсутствие опыта, но знание математической статистики и методов статистического анализа данных (кластеризация, регрессионный, факторный, дисперсионный и корреляционный анализы) опыт автоматизации или оптимизации процессов опыт работы с СУБД: Teradata или Oracle или Greenplum как преимущество; с языками программирования: SQL и Python опыт работы с Power BI или Сonfluence или QLIK Sense или Visio будет преимуществом  Условия:  работа в динамично развивающейся экосистеме стабильный оклад и систему непрерывных бонусов ДМС и программы лояльности для сотрудников в рамках всей экосистемы безграничные возможности горизонтального и вертикального роста возможность постоянного обучения на базе внутреннего университета экосистемы или внешних партнеров работа в командах прогрессивно мыслящих и энергичных людей рабочее место в современном офисе с возможностью отдыха в течение дня: lounge-зоны, зоны коворкинга, кафе, оборудованные кухни, спортивный зал и спортивные групповые программы
# 112                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Блок &quot;Сеть продаж&quot; курирует все физические каналы касания клиента с экосистемой (отделения, банкоматы, агентская сеть и тд). Мы разрабатываем и внедряем end-to-end решения на основе машинного обучения в бизнес-процессы, связанные с обслуживанием клиентов. Сейчас мы ищем Аналитика SQL в команду, которая развивает интеллектуальную систему управления для руководителей подразделений блока Сети продаж.   Чем придется заниматься:   Проверка гипотез на больших массивах данных (в т.ч. при необходимости с использованием методов машинного обучения) Выявление ключевых факторов и причинно-следственных связей Статистический анализ данных Работа с Teradata, GreenPlum    Наши ожидания:  Умение проверять гипотезы с использованием математических инструментов; Опыт написания запросов, хранимых процедур и оптимизации запросов на SQL; Высокий уровень использования Excel c макросами; Опыт анализа данных с использованием Python: Jupyter, библиотеки; Опыт работы с реляционными СУБД (PostgreSQL, GreenPlum); Опыт создания аналитического хранилища (DWH);    Мы предлагаем:  Возможность участвовать в амбициозных проектах крупнейшего Банка страны. Разнообразные и интересные задачи в области анализа и исследования бизнес-показателей. Возможности для профессионального и личностного роста в динамично развивающемся коллективе большой компании. Профессиональное развитие в области работы с данными. Конкурентная заработная плата. Cоциальный пакет (ДМС, НПФ, спортзал).
# 113                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Наша команда Цель нашей Команды - высокая эффективность процессов Блока Корпоративно-инвестиционный бизнес. Мы ищем Менеджера с компетенциями оценки эффективности расходов на IT-инфраструктуру и проекты, который будет настраивать внутренние бизнес-процессы для взвешенного подхода к расходам и с целью максимальной отдачи на вложенные ресурсы. Задачи Если Вы знакомы с принципами IT-бюджета, финансовой логикой прямых и накладных расходов, способны систематизировать и анализировать большой объем информации, выстраивать процесс принятия решений в бюджетировании, если Вы коммуникабельны, креативны, и готовы аргументированно отстаивать свою позицию, ждем в нашу Команду. Мы ожидаем  Знания структуры ресурсов и расходов в ИТ; Умение анализировать бизнес-нужды и вычленять предполагаемые направления, требующие проработки на основе аналитики больших данных строить гипотезы, искать взаимосвязи и предлагать оптимизационные мероприятия для снижения расходов на ИТ-инфраструктуру Умение выстраивать архитектуру решений, описывать основную идею, выстраивать признаки для моделей, умение выстраивать гипотезы и осуществлять оценку качества результатов модели Умение интерпретировать результаты расчетов и моделей, формировать отчетность для вышестоящего руководства. Креативный подход, способность аргументированно отстаивать свою позицию; Умение работать в команде и коммуницировать со смежными подразделениями в рамках своих задач; Power Point, Excel (сводные таблицы); Будет плюсом: знание SQL, Python, Big data, принципов формирования внутренних тарифных моделей.  Условия  Современный Agile-офис, Кутузовский 32: парковка, спортзал, зоны отдыха, приятная атмосфера ДМС с первого дня Крупнейшее DS&amp;AI community - более 600 DS банка, включая: Регулярный обмен знаниями, опытом и лучшими практиками Интерактивные лекции и мастер-классы от ведущих ВУЗов и экспертов технологических компаний Дайджест о самых последних разработках в области DS&amp;AI и отчеты с крупнейших конференций мира Регулярные внутренние митапы
# 129                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Обязанности  Мониторинг метрик контроля качества данных и их автоматизация; Анализ причин срабатывания проверок (метрик), их локализация и устранение; Взаимодействие с сотрудниками смежных подразделений по вопросам контроля и повышения качества данных; Ответы на Ad-hoc запросы от бизнеса с помощью детального анализа данных; Разработка бизнес-требований, прототипов и постановка ТЗ по доработкам потоков данных для их реализации в системах; Участие в тестировании доработок;  Требования  Высшее техническое или финансовое образование; Опыт работы с: SQL/Oracle, Excel, Jira, GreenPlum; Стрессоустойчивость, внимательность, аналитический склад ума; Коммуникабельность: умение общаться и с заказчиками (бизнесом) и разработчиками (ИТ); Знание английского языка (базовый); Знание принципов организации и стандартов архитектуры автоматизированных систем в Банке (рекомендуется); Знание основ Agile (рекомендуется).  Условия  Профессиональное обучение, семинары, тренинги, конференции; Годовые премии; ДМС, сниженные ставки по кредитованию, программы лояльности для сотрудников; Самые инновационные, амбициозные проекты и задачи; Комфортный офис «Sbergile Home» с просторными опенспейсами, лаунж зонами, кафе, рестораном и оборудованными кухнями; Бесплатный фитнес-зал; Место работы – БЦ Президент Плаза (м. Кутузовская).
# 132                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   В команду &quot;Кампании продаж&quot; Корпоративно-инвестиционного блока ищем Аналитика данных. Наша команда занимается:<br />- разработкой процесса выставления кампаний продаж для корпоративных клиентов; - формированием предложений по продуктам банка и экосистемы для организаций сегментов Средний+ и Рег. Госсектор, доставкой до канала продаж, получением откликов и их обработка. Обязанности:  Взаимодействие со стейкхолдерами, уточнение требований Настройка процесса подготовки предложений для отправки в канал Тестирование функционала, разработанного IT, перед релизом на ПРОМ Подведение итогов отработки предложений в канале, формирование предложений по улучшению Подготовка аналитических расчетов для поиска зон роста доходов от кампаний продаж, улучшение качества предложений Проверка гипотез на основе подготовленной статистики, интерпретация результата, улучшение процесса путем доработок  Требования:  Уверенное знание SQL (любые виды соединений таблиц, группировки, аналитические функции). Опыт работы с данными, анализ с целью ответа на поставленный вопрос Умение формализовать требования(БТ, ТЗ) для команд IT на разработку/доработку функционала Опыт работы с Jira, ведения документации в Confluence Опыт кросс командного взаимодействия, коммуникабельность Умение критически оценивать предлагаемые другими изменения процесса  Преимуществом будет:  Понимание особенностей банковских продуктов и их учета Опыт проведения маркетинговых кампаний продаж Опыт работы в финансовой сфере  Условия:  Официальное оформление по ТК РФ, белую заработную плату (оклад + премии). Современный офис: Кутузовский пр 32к1, а также возможность удаленной работы. Полный социальный пакет + корпоративный пакет (ДМС, страхование от несчастных случаев, дисконт-программы от компаний партнеров, корпоративные мероприятия, фитнес, тренажерные залы). Интересные задачи. График работы: 5/2. Работа по методологии Agile в дружной команде.
# 206   Общее описание: 1. Аналитика и разработка витрин данных в контуре Hadoop для сервисов Мобильного приложения СБОЛ. Как пример – сервис Всего средств, в котором отображаются данные по всем продуктам клиента как на текущий момент, так и на горизонте прошедших 5 лет, что позволяет клиентам оценить эффективность взаимодействия со Сбером 2. Участие в интеграционных проектах по автоматизации процессов. Как пример – автоматизация процесса Сервисных коммуникаций с клиентом – необходимо разработать витрины данных и интеграцию с контактным центром для последующих контактов с клиентом по выявлению мисселлинга 3. Проект по реализации базового слоя данных Блока Управление Благосостоянием – анализ и разработка витрин данных по продуктам Пенсионного Фонда, Страховых компаний (Сбербанк Страхование и Сбербанк Страхование Жизни), Управляющей компании. 4. Реализация витрин данных для внутренней отчетности, в т.ч. управленческой, по динамике продаж, доходности продуктов, квитовке платежей и т.п. в контуре Hadoop 5. Направление по работе с качеством данных – как методология (что такое «качество»), так и техническая реализация процессов проверки качества данных и дэшборда по качеству. Тебе предстоит  Взаимодействие с заказчиками, анализ, уточнение, согласование бизнес и функциональных требований к витринам данных, интеграционным решениям, решениям потоковой обработки данных Анализ и профилирование данных систем-источников, подготовка прототипов, постановка ТЗ для промышленной разработки Проектирование логической и физической модели данных, интеграционных схем Разработка сценариев тестирования (написание технических и бизнес проверок), координация работ по тестированию (включая подготовку тестовых данных), выявление ошибок и дефектов разработки Участие в демонстрациях и сдаче продукта заказчику Подготовка пользовательской документации, ПМИ Участие во внедрении и сопровождении программного продукта  Мы ждем от кандидата:    Аналитический склад мышления, системный подход, опыт взаимодействия с заказчиками Опыт работы с данными: анализ, профилирование, оценка качества данных Опыт работы с основными реляционными базами данных: Teradata, Oracle, MS SQL Опыт работы с инструментами Hadoop Знание SQL (аналитические функции, сложные запросы, принципы оптимизации запросов) Опыт написания функциональных и технических требований к разрабатываемой системе, написания технических проектов ИТ-решений, согласования документации с заказчиками и разработчиками Понимание принципов разработки сценариев тестирования  Будет плюсом, если ты:  Знание основных продуктов банка, понимание жизненного цикла и экономического смысла продуктов Опыт работы с решениями потоковой обработки данных Опыт участия в интеграционных проектах  Что мы предлагаем:  Официальное трудоустройство согласно ТК РФ; Бессрочный трудовой договор; Работа в крупнейшем банке России; Конкурентная компенсация (оклад и премии по результатам деятельности); График работы 5\2 с 9:00 до 18:00; ДМС сразу с начала работы, страхование от несчастных случаев и тяжелых заболеваний; Материальная помощь и социальная поддержка, корпоративная пенсионная программа; Дисконт-программы от множества компаний партнеров; Бесплатный фитнес на территории работодателя; Свободный дресс-код; Профессиональное обучение, семинары, тренинги, конференции, корпоративная библиотека; Команда профессионалов, готовых поддержать Ваши инициативы; Интересные и масштабные проекты и задачи; Возможность работы с новыми технологиями; Возможность прокачать и hard и soft skills; Яркая и насыщенная корпоративная жизнь.
# 230                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Команда Интеллектуального IVR работает над автоматизацией обслуживания звонков розничных клиентов в колл-центр банка. Мы ищем аналитика данных для усиления команды в части анализа работы продукта, а также поиска скрытых закономерностей в поведении пользователей. Обязанности  Анализ воронок клиентских путей в продуктах Поиск точек роста продукта на основе истории взаимодействия клиентов с банком Проведение и анализ продуктовых пилотов Прототипирование дашбордов и написание аналитических отчетов Взаимодействие с командами Big Data в банке в части обмена опытом  Требования  Владение SQL, PySpark, Python для обработки и анализа данных Знания статистики для работы с гипотезами и доверительными интервалами Опыт проведения а/б тестов Умение работать с большими массивами данных Навыки презентации и визуализа  Будет плюсом:  Опыт работы с NLP библиотеками (nltk/gensim), т.к. иногда придется работать с текстовыми данными Опыт работы с QlikView/QlikSense Опыт работы с колл центрами и автоматизацией обслуживания обращений  Условия  полный рабочий день, но гибкий график работы (можно выбрать режим начала работы в промежутке 7:00 - 10:30) достойная заработная плата (оклад + внушительные премии) оформление по ТК РФ социальный пакет (ДМС) комфортный офис Agile Home возможность посещения конференций, обучения и сертификации за счет компании (в т.ч. английский язык) программа льготного кредитования в Сбербанке дисконт-программы от множества компаний партнеров возможность принять участие в других крупных и уникальных проектах банка
# 305                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Кто мы? Продуктовая команда &quot;Индустрии Рекламы&quot; Сбера, которая ищет тебя - специалиста в области разработки! Наш продукт - модуль &quot;Автоматическая модерация и разметка рекламных кампаний; рекламодателей; рекламных площадок&quot;. Этот Модуль - часть создаваемой платформы по управлению рекламой на всех digital-поверхностях Сбера и его партнеров. Наша цель - определение правильных и пригодных кампаний от всех рекламодателей, которые хотят разместить рекламные объявления на digital-поверхностях экосистемы Сбера и его партнеров. Если ты талантливый и амбициозный специалист в сфере ИТ, если ты хочешь быть причастными к созданию лучших продуктов для лучших клиентов и уверенно отвечать за результаты, то мы рады принять тебя в команду. Обязанности: Команда качества ранжирования занимается всем циклом отбора рекламы в SberAds. Мы занимаемся как непосредственно машинным обучением, так и его технической инфраструктурой. Работая бок о бок с командой сервисов ранжирования создаются сервисы, которые в реальном времени подбирают для пользователей наиболее релевантную рекламу. Качество прогнозов наших моделей напрямую влияет на выручку SberAds и поэтому основная наша цель это рост качества алгоритмов.   В рамках данной позиции предстоит:  Проведение ad-hoc аналитики на данных рекламы (Hive, Spark, SQL); Визуализация отчетности в BI инструментах (SuperSet, Qlik); Работа с алгоритмами ML, подготовка обучающих выборок, анализ и сбор метрик.  Требования:  Хорошие знания SQL, опыт работы с одной из реляционной БД - Oracle/PostgreSQL/mySQL/MS SQL Server; Уверенная работа с Python; Опыт аналитики с использованием инструментов Spark Streaming, Hbase, Spark, Kafka, Hive, Impala, Hue и т.д.; Навыки построения аналитических отчетов и дашбордов в BI инструментах. Понимание принципов модели распределенных вычислений, принципов организации Data Lake/DWH; Понимание подходов к организации разработки CI/CD.  Условия:  Официальное трудоустройство согласно ТК РФ; Белая заработная плата (оклад + годовая премия); Страхование (от несчастных случаев, ДМС); Оздоровительные программы для детей сотрудников; Возможность обучения за счет компании; Выплаты материальной помощи в особых/чрезвычайных случаях; Дисконт-программы от компаний партнеров (фитнес, страхование, туризм); Льготное кредитование; Корпоративные цены на абонементы в крупные фитнес-сети; Комфортный офис и график работы 5/2
# 311                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       <em>Мы команда Управления Комплаенс ищем нового Middle Data analyst. Основной задачей Управления Комплаенс является построение стратегий, основанных на статистистическом анализе и аналитике данных, выявления схем легализации доходов, полученных преступным путем.</em> Новому Data analyst нужно будет работать с таблицами на sql/spark, работать с графами связей, разрабатывать прототипы витрин, общаться с инженерами, методологами, изучать предметную область и формировать предложения по улучшения процесса выявления. Обязанности  Разработка стратегий принятия решений в области компалаенс риска; Изучение выявления схем легализации и формирование предложений по их изменению и автоматизации; Обработка данных и статистический анализ данных и гипотез; Подготовка прототипа для пилотирования/внедрения моделей; Мониторинг разработанных моделей; Определение требований к качеству данных; Подготовка аналитических исследований в области выявления схем легализации доходов, полученных преступным путем;  Требования  Профильное высшее образование, опыт работы в области анализа данных не менее года; Опыт работы с базами данных (SQL); Знание Python / Spark; Хорошее знание теории вероятностей и математической статистики; Хорошие коммуникативные навыки; Хорошие аналитические способности; Желателен опыт разработки стратегий принятия решений (риск политик)  Условия  Ипотека выгоднее на 4% для каждого сотрудника и льготные условия кредитования; Бесплатная подписка СберПрайм+; Скидки на продукты компаний-партнеров; ДМС с первого дня и льготное страхование для близких; Корпоративная пенсионная программа; Обучение за счет Компании: онлайн курсы в Виртуальной школе Сбера и неограниченный доступ к библиотеке, обучение в Корпоративном университете, Тренинги, митапы и возможность получить новую квалификацию; Крупнейшее DS&amp;AI community - более 600 DS банка, включая: регулярный обмен знаниями, опытом и лучшими практиками, интерактивные лекции и мастер-классы от ведущих ВУЗов и экспертов технологических компаний, дайджест о самых последних разработках в области DS&amp;AI и отчеты с крупнейших конференций мира, регулярные внутренние митапы.
# 338                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Ищем аналитика данных (Лист-менеджера) в команду розничного бизнеса для анализа данных по процессам взаимодействия с клиентами, эффективности кампаний продаж, достижению бизнес-показателей. Обязанности Обязанности:  формирование кампаний продаж на клиентов Банка для продвижения продуктов и сервисов Банка (выстраивание алгоритмов приоритизации предложений) посредством SQL-запросов, работой в CRM, SAS разработка аналитической отчетности анализ данных по процессам взаимодействия с клиентами Банка, эффективности кампаний продаж, достижению бизнес-показателей (средствами Teradata (SQL), Python, в перспективе - Hive, Impala, Spark) понимание процессов коммуникации с клиентами (построение и проверка бизнес-гипотез) при необходимости визуализация данных (PowerPoint), в том числе с использованием специализированных BI-инструментов (Qlik View)  Требования  высшее образование по направлению: прикладная математика/физика/ИТ/финансы желателен опыт работы в банковской сфере, понимание внутрибанковских процессов и знание банковских продуктов и услуг отличное знание Excel (VBA будет являться преимуществом) владение методами анализа данных и инструментами подготовки отчетности опыт работы с базами данных, навыки написания сложных SQL-запросов обязательны (Teradata, Oracle, SAS, MS SQL, GP) опыт работы с инструментами визуализации данных является преимуществом (в идеале - Qlik View) знание Python является преимуществом  Условия  полный рабочий день, но гибкий график работы (можно выбрать режим начала работы в промежутке 7:00 - 10:30) достойная заработная плата (оклад + внушительные премии) оформление по ТК РФ социальный пакет (ДМС) комфортный офис Agile Home возможность посещения конференций, обучения и сертификации за счет компании (в т.ч. английский язык) программа льготного кредитования в Сбербанке дисконт-программы от множества компаний партнеров возможность принять участие в других крупных и уникальных проектах банка
# 346                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          В SberData мы создаем централизованное хранилище данных всего Сбера. Это более 350 источников данных и 100+ Пб информации, заказ и получение данных за 15 минут и современный технологический стек работы с данными, включая собственные сборки СУБД на базе Hadoop и Greenplum. Находимся в поисках Руководителя направления аналитики в команду <em>«Контроль качества данных»</em> для развития процессов с последующим внедрением изменений. <em>Первоочередная задача</em>- внедрение новой роли/участников в процессы контроля качества данных “Владелец предметной области” Про команду: Мы обеспечиваем контроль качества данных крупнейшего банка России, и одного из крупнейших в мире. От нашей деятельности зависит правильность информации, которая используется для разработки новых бизнес-сервисов, построения AI и ML моделей, различной отчетности. В ходе работы вы познакомитесь почти со всеми автоматизированными системами Банка, всеми направлениями бизнеса, и многими интересными людьми, сможете понять как данные влияют на задачи бизнеса и почему Заказчику нужны качественные данные. Чем предстоит заниматься · Подготовка стратегии оптимизации процессов · Анализ задач и проблем, определение возможных путей решения · Подготовка презентационных материалов, представление их и утверждение с участниками процесса · Внедрение изменений процессов, разработка планов проведения работ, организация и контроль выполнения, управление рисками и изменениями Что для этого необходимо · Высшее образование · Опыт успешно завершенных проектов в бизнес-аналитике, ИТ-аналитике, навыки концептуального мышления · Опыт успешно завершенных работ в области руководства проектами/внедрениями · Грамотная устная и письменная речь · Знание Jira, PowerPoint · Знание принципов построения DWH · Знание принципов обеспечения качества данных в АС Условия  Офис БЦ Чайка Плаза 10 - м.Нагатинская/Тульская/Верхние Котлы/Коломенская Профессиональный рост в команде дружных профессионалов. Бесплатный фитнес-зал в БЦ. Профессиональное обучение, семинары, тренинги, конференции, корпоративная библиотека. ДМС, страхование жизни. Самые инновационные, амбициозные проекты и задачи. Свободный дресс-код. Гибкий график для оптимального баланса работы и личной жизни. Льготные кредиты и корпоративные скидки. Конкурентная компенсация (оклад и премии по результатам работы).
# ...
# 913                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            В SberData мы создаем централизованное хранилище данных всего Сбера. Это более 350 источников данных и 100+ Пб информации, заказ и получение данных за 15 минут и современный технологический стек работы с данными, включая собственные сборки СУБД на базе Hadoop и Greenplum. Про команду управления корпоративных данных: Команда обеспечивает контроль качества данных экосистемы Сбера. От их деятельности зависит правильность информации, которая используется для разработки новых бизнес-сервисов, построения AI и ML моделей, различной отчетности. Состав команды: В команде работает более 40 профессионалов в области обеспечения качества данных. Про наш стек технологий:  разработка ведется на разнообразных базах и хранилищах данных: Teradata, Oracle, GreenPlum, Hadoop в наличии отдельные стенды разработки (DEV), тестирования (MT, IFT, ПСИ) и ПРОМ, связанные сквозной трубой DevOPS.  Чем предстоит заниматься: В ходе работы вы познакомитесь почти со всеми автоматизированными системами Банка, всеми направлениями бизнеса, и многими интересными людьми, сможете понять как данные влияют на задачи бизнеса и почему заказчику нужны качественные данные. Основные задачи:  реализация требований к качеству данных Банка анализ требований уточнение деталей бизнес-требования с заказчиками требований и поставщиками данных постановка задачи для разработки приемка результата разработки согласование результатов реализации требования с заказчиками.  От кандидата мы хотим видеть:  опыт в сфере работы с данными от 3 лет, в том числе в банковском секторе не менее 1-го года знания банковских основ, процессов и стандартов умение интерпретировать и презентовать данные знание SQL на уровне написания средних запросов аналитический склад ума, умение самостоятельно разбираться в новом материале, документации  Мы предлагаем:  оклад + годовая премия работа в офисе офис: г. Москва, м. Верхние котлы / Тульская / Нагатинская, бизнес центр &quot;Чайка плаза 10&quot; график работы: 5\2 с 9:00 до 18:00 с возможностью корректировать начало-окончание рабочего дня бессрочный трудовой договор расширенный ДМС с первого дня и льготное страхование для близких бесплатный фитнес-зал в офисе бесплатную подписку СберПрайм+ и скидки на продукты компаний-партнеров корпоративное обучение за счет компании корпоративную пенсионную программу.
# 1013                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    SberData – департамент по управлению данными всего Сбербанка. SberData строит централизованное хранилище данных, объем которого уже превышает 10 ПБ. Это продуктово-ориентированная инженерная команда с функциями развития выделенных технологических направлений, отражающих новый подход Сбербанка к данным и к применению AI. <br /><em>О команде:</em> Команда занимается разработкой инструментария построения Единого Семантического Слоя (Хранилища) на новейших технологиях:  ETL-платформа Ab Initio (крупный игрок мирового рынка, первое внедрение в России) стек Hadoop (HDFS, Parquet, Spark, Hive, HBase и т.д.) MPP-БД (Teradata, Greenplum)  <em>В роли системного архитектора предстоит:</em> Системный анализ и проектирование инструментария построения Хранилища данных:  Участие в обсуждении Solution-архитектуры Взаимодействие с командами разработки инструментария - совместное проектирование, контроль реализации Участие в сдаче готового функционала заказчикам и потребителям  <em>От кандидата мы ожидаем:</em>  SQL – уровень эксперт. Hadoop (HDFS, Hive, Impala, Spark, HBase, Kafka). Знание практик и инструментария DevOps. Практический опыт создания ETL для хранилищ данных и витрин данных (Informatica, Oracle Integrator, Datastage и т.д.). Знание принципов и методик гибкой разработки (Agile) Английский язык – на уровне чтения технической документации, ведения деловой переписки.  <em>Преимуществом будет:</em>  Языки программирования высокого уровня (Java, C++ и т.д.). Опыт использования инструментов гибкой разработки: Jira, Confluence, Jenkins, BitBucket  <em>С нас:</em>  Офис БЦ &quot;Чайка Плаза&quot; м.Нагатинская/Тульская/Нижние Котлы/Коломенская Интересные и масштабные проекты и задачи Бесплатный фитнес-зал Профессиональное обучение, семинары, тренинги, конференции, корпоративная библиотека Работа в крупнейшем банке России Трудоустройство согласно ТК РФ ДМС с первого дня, страхование от несчастных случаев и тяжелых заболеваний Материальная помощь и социальная поддержка, корпоративная пенсионная программа Свободный дресс-код Конкурентная материальная компенсация (оклад и премия за год по результатам деятельности) Яркая и насыщенная корпоративная жизнь Дисконт-программы от множества компаний партнеров
# 1081                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 В SberData мы создаем централизованное хранилище данных всего Сбера. Это более 350 источников данных и 100+ Пб информации, заказ и получение данных за 15 минут и современный технологический стек работы с данными, включая собственные сборки СУБД на базе Hadoop и Greenplum.   Предметная область: Наша команда создает и развивает продукт для построения Data Lineage на различных технологических стеках хранения и преобразовании информации ( от традиционных РСУБД : Oracle/PostgreSQL/GreenPlum до Hadoop: Hive/Spark). Перед командой стоит задача по созданию продукта не только в рамках платформы Фабрики, но и выхода в экосистему Сбербанка, а далее и на внешний рынок. Data lineage – информация, которая описывает движение данных от источника их происхождения по точкам обработки и применения. В мире Big Data, когда информации становится все больше, Data lineage позволяет управлять данными, реализуя следующие задачи:  Обеспечение качества данных за счет однозначной идентификации их источников; Повышение доверия к данным через прозрачность всех процессов работы с ними; Предоставление метаданных и сведений об их изменении в точках трансформации данных.    Чем предстоит заниматься:  исследование данных различных систем источников Data Linage формирование требований по сбору, хранению и распространению фактического Data Lineage проектирование единой модели Data Lineage проектирование моделей данных для систем источников синхронизация и устранение разрывов единой модели данных, моделей источников, модели приёмников постановка требований и разработка процессов обработки и трансформации Data Lineage (Spark 2,3, Hive) участие в разработке/актуализации архитектуры.    Кто нам нужен:  опыт проектирования и описания процессов знание современных инструментов описания процессов опыт работы с форматами json, xml, xsd, wsdl опыт работы с RDBMS, проектирование структуры, высокий уровне знания SQL знание REST/SOAP опыт использования экосистемы Hadoop (Spark, Hive, Spark ML), Scala или python развитые коммуникативные навыки    Сбер - это:  профессиональный рост в команде экспертов профессиональное обучение, семинары, тренинги, конференции, корпоративная библиотека ДМС, страхование жизни самые инновационные, амбициозные проекты и задачи свободный дресс-код гибкий график для оптимального баланса работы и личной жизни льготные кредиты и корпоративные скидки конкурентная компенсация (оклад и премии по результатам деятельности).
#
#                                                                                                                                      skills
# 105                          [SQL, Python, Статистический анализ, Qlik Sense, Математическая статистика, Анализ данных, Excel, Базы данных]
# 112                                                                                                                 [SQL, Teradata, Python]
# 113                                                                                                                                      []
# 129                                                                                                                                      []
# 132        [Atlassian Jira, Atlassian Confluence, Аналитическое мышление, SQL, MS PowerPoint, Agile, Анализ данных, Базы данных, Аналитика]
# 206                                                                                          [SQL, Atlassian Jira, Kafka, PostgreSQL, Java]
# 230                                                                                                                                      []
# 305                                                                                    [Python, SQL, Data Mining, Oracle BI, Анализ данных]
# 311                                                                                                                                      []
# 338                                                                                                                                      []
# 346                                                                                                                                      []
# 418                                                                                                                                      []
# 487   [Работа в команде, Умение работать в команде, Умение работать в коллективе, Способность обучать других, Материальная ответственность]
# 552                                                                    [SQL, Data Analysis, Big Data, Teradata, Python, Excel, VBA, ORACLE]
# 643                                                                                                                                      []
# 783                                                                                                         [DWH, Hadoop, Spark, Greenplum]
# 913                                                                                                                                      []
# 1013                                                                                             [SQL, Java, Atlassian Jira, ETL, Big Data]
# 1081                                                                                             [Python, SQL, Spark, Big Data, PostgreSQL]

# %%
len(df_hh_da)
# Out:
# 19

# %%
list_da_vac_skills = df_hh_da['key_skills'].apply(lambda t: ','.join([x.get('name') for x in t])).tolist()
top_da_skills = Counter(x for x in ','.join(list_da_vac_skills).split(',') if x != '')
top_da_skills.most_common()
# Out:
# [('SQL', 8),
#  ('Python', 5),
#  ('Анализ данных', 3),
#  ('Atlassian Jira', 3),
#  ('Big Data', 3),
#  ('Excel', 2),
#  ('Базы данных', 2),
#  ('Teradata', 2),
#  ('PostgreSQL', 2),
#  ('Java', 2),
#  ('Spark', 2),
#  ('Статистический анализ', 1),
#  ('Qlik Sense', 1),
#  ('Математическая статистика', 1),
#  ('Atlassian Confluence', 1),
#  ('Аналитическое мышление', 1),
#  ('MS PowerPoint', 1),
#  ('Agile', 1),
#  ('Аналитика', 1),
#  ('Kafka', 1),
#  ('Data Mining', 1),
#  ('Oracle BI', 1),
#  ('Работа в команде', 1),
#  ('Умение работать в команде', 1),
#  ('Умение работать в коллективе', 1),
#  ('Способность обучать других', 1),
#  ('Материальная ответственность', 1),
#  ('Data Analysis', 1),
#  ('VBA', 1),
#  ('ORACLE', 1),
#  ('DWH', 1),
#  ('Hadoop', 1),
#  ('Greenplum', 1),
#  ('ETL', 1)]
